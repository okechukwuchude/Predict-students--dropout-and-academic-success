# %%
import numpy as np
import pandas as pd
import ydata_profiling as pp
import math
import random
import seaborn as sns
import matplotlib.pyplot as plt
import time 

st = time.time()

# %matplotlib inline

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score, confusion_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel, SelectKBest, RFE, chi2
from sklearn.model_selection import learning_curve

# models
from sklearn.linear_model import LogisticRegression, Perceptron, RidgeClassifier, SGDClassifier, LassoCV
from sklearn.svm import SVC, LinearSVC, SVR
from sklearn.ensemble import RandomForestClassifier 
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# NN models
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
#from keras.wrappers.scikit_learn import KerasClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
#importing the data
data = pd.read_csv(r"C:\Users\okechukwu chude\Documents\MOdeling and optimisation\Predict students' dropout and success\Predict-students--dropout-and-academic-success\dataset.csv")

# %% [markdown]
# Data Exploration

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
#
# [3 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
#  9   Mother's occupation                             4424 non-null   int64
#  10  Father's occupation                             4424 non-null   int64
#  11  Displaced                                       4424 non-null   int64
#  12  Educational special needs                       4424 non-null   int64
#  13  Debtor                                          4424 non-null   int64
#  14  Tuition fees up to date                         4424 non-null   int64
#  15  Gender                                          4424 non-null   int64
#  16  Scholarship holder                              4424 non-null   int64
#  17  Age at enrollment                               4424 non-null   int64
#  18  International                                   4424 non-null   int64
#  19  Curricular units 1st sem (credited)             4424 non-null   int64
#  20  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  21  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  22  Curricular units 1st sem (approved)             4424 non-null   int64
#  23  Curricular units 1st sem (grade)                4424 non-null   float64
#  24  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  25  Curricular units 2nd sem (credited)             4424 non-null   int64
#  26  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  27  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  28  Curricular units 2nd sem (approved)             4424 non-null   int64
#  29  Curricular units 2nd sem (grade)                4424 non-null   float64
#  30  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  31  Unemployment rate                               4424 non-null   float64
#  32  Inflation rate                                  4424 non-null   float64
#  33  GDP                                             4424 non-null   float64
#  34  Target                                          4424 non-null   object
# dtypes: float64(5), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
#checking for missing values
data.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %%
data['Target'].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %% [markdown]
# Data Visualisation

# %%
pd.crosstab(data.Target,['Target']).plot(kind='bar')
# Out:
# <Axes: xlabel='Target'>

# %%
pd.crosstab(data.Target,['Target']).plot(kind='pie',subplots=True,autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='Target'>], dtype=object)

# %%
#Dropping rows for enrolled students as this does not indicate the future outcome
data = data.drop(data[data['Target'] == 'Enrolled'].index)

# %%
label_encoder = LabelEncoder()

# Apply label encoding to non-numerical columns
columns_to_encode = ['Target']
for column in columns_to_encode:
    data[column] = label_encoder.fit_transform(data[column])

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
#for i in data.columns: 
 #   sns.countplot(x = i, data = data)
  #  plt.show()

# %%
# Create a heat map
correlation_matrix = data.corr()

# Plot the heatmap
plt.figure(figsize=(26, 12))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# %%
train = data.copy()
target = train.pop('Target')
train.head(2)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
#
#    Inflation rate   GDP
# 0             1.4  1.74
# 1            -0.3  0.79
#
# [2 rows x 34 columns]

# %% [markdown]
# Undersampling

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from imblearn) (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.11.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.under_sampling import RandomUnderSampler

# Instantiate the RandomUnderSampler object
rus = RandomUnderSampler(random_state=42)  # Set a random state for reproducibility

# Perform undersampling
train, target = rus.fit_resample(train, target)

# %% [markdown]
# Feature Selection

# %%
num_features_opt = 25   # the number of features that we need to choose as a result
num_features_max = 35  
features_best = []

# %% [markdown]
# Uisng Pearson Correlation

# %%
# Threshold for removing correlated variables
threshold = 0.9

def highlight(value):
    if value > threshold:
        style = 'background-color: pink'
    else:
        style = 'background-color: palegreen'
    return style

# Absolute value correlation matrix
corr_matrix = data.corr().abs().round(2)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
upper.style.format("{:.2f}").applymap(highlight)
# Out:
# <style type="text/css">
# #T_755e4_row0_col0, #T_755e4_row0_col1, #T_755e4_row0_col2, #T_755e4_row0_col3, #T_755e4_row0_col4, #T_755e4_row0_col5, #T_755e4_row0_col6, #T_755e4_row0_col7, #T_755e4_row0_col8, #T_755e4_row0_col9, #T_755e4_row0_col10, #T_755e4_row0_col11, #T_755e4_row0_col12, #T_755e4_row0_col13, #T_755e4_row0_col14, #T_755e4_row0_col15, #T_755e4_row0_col16, #T_755e4_row0_col17, #T_755e4_row0_col18, #T_755e4_row0_col19, #T_755e4_row0_col20, #T_755e4_row0_col21, #T_755e4_row0_col22, #T_755e4_row0_col23, #T_755e4_row0_col24, #T_755e4_row0_col25, #T_755e4_row0_col26, #T_755e4_row0_col27, #T_755e4_row0_col28, #T_755e4_row0_col29, #T_755e4_row0_col30, #T_755e4_row0_col31, #T_755e4_row0_col32, #T_755e4_row0_col33, #T_755e4_row0_col34, #T_755e4_row1_col0, #T_755e4_row1_col1, #T_755e4_row1_col2, #T_755e4_row1_col3, #T_755e4_row1_col4, #T_755e4_row1_col5, #T_755e4_row1_col6, #T_755e4_row1_col7, #T_755e4_row1_col8, #T_755e4_row1_col9, #T_755e4_row1_col10, #T_755e4_row1_col11, #T_755e4_row1_col12, #T_755e4_row1_col13, #T_755e4_row1_col14, #T_755e4_row1_col15, #T_755e4_row1_col16, #T_755e4_row1_col17, #T_755e4_row1_col18, #T_755e4_row1_col19, #T_755e4_row1_col20, #T_755e4_row1_col21, #T_755e4_row1_col22, #T_755e4_row1_col23, #T_755e4_row1_col24, #T_755e4_row1_col25, #T_755e4_row1_col26, #T_755e4_row1_col27, #T_755e4_row1_col28, #T_755e4_row1_col29, #T_755e4_row1_col30, #T_755e4_row1_col31, #T_755e4_row1_col32, #T_755e4_row1_col33, #T_755e4_row1_col34, #T_755e4_row2_col0, #T_755e4_row2_col1, #T_755e4_row2_col2, #T_755e4_row2_col3, #T_755e4_row2_col4, #T_755e4_row2_col5, #T_755e4_row2_col6, #T_755e4_row2_col7, #T_755e4_row2_col8, #T_755e4_row2_col9, #T_755e4_row2_col10, #T_755e4_row2_col11, #T_755e4_row2_col12, #T_755e4_row2_col13, #T_755e4_row2_col14, #T_755e4_row2_col15, #T_755e4_row2_col16, #T_755e4_row2_col17, #T_755e4_row2_col18, #T_755e4_row2_col19, #T_755e4_row2_col20, #T_755e4_row2_col21, #T_755e4_row2_col22, #T_755e4_row2_col23, #T_755e4_row2_col24, #T_755e4_row2_col25, #T_755e4_row2_col26, #T_755e4_row2_col27, #T_755e4_row2_col28, #T_755e4_row2_col29, #T_755e4_row2_col30, #T_755e4_row2_col31, #T_755e4_row2_col32, #T_755e4_row2_col33, #T_755e4_row2_col34, #T_755e4_row3_col0, #T_755e4_row3_col1, #T_755e4_row3_col2, #T_755e4_row3_col3, #T_755e4_row3_col4, #T_755e4_row3_col5, #T_755e4_row3_col6, #T_755e4_row3_col7, #T_755e4_row3_col8, #T_755e4_row3_col9, #T_755e4_row3_col10, #T_755e4_row3_col11, #T_755e4_row3_col12, #T_755e4_row3_col13, #T_755e4_row3_col14, #T_755e4_row3_col15, #T_755e4_row3_col16, #T_755e4_row3_col17, #T_755e4_row3_col18, #T_755e4_row3_col19, #T_755e4_row3_col20, #T_755e4_row3_col21, #T_755e4_row3_col22, #T_755e4_row3_col23, #T_755e4_row3_col24, #T_755e4_row3_col25, #T_755e4_row3_col26, #T_755e4_row3_col27, #T_755e4_row3_col28, #T_755e4_row3_col29, #T_755e4_row3_col30, #T_755e4_row3_col31, #T_755e4_row3_col32, #T_755e4_row3_col33, #T_755e4_row3_col34, #T_755e4_row4_col0, #T_755e4_row4_col1, #T_755e4_row4_col2, #T_755e4_row4_col3, #T_755e4_row4_col4, #T_755e4_row4_col5, #T_755e4_row4_col6, #T_755e4_row4_col7, #T_755e4_row4_col8, #T_755e4_row4_col9, #T_755e4_row4_col10, #T_755e4_row4_col11, #T_755e4_row4_col12, #T_755e4_row4_col13, #T_755e4_row4_col14, #T_755e4_row4_col15, #T_755e4_row4_col16, #T_755e4_row4_col17, #T_755e4_row4_col18, #T_755e4_row4_col19, #T_755e4_row4_col20, #T_755e4_row4_col21, #T_755e4_row4_col22, #T_755e4_row4_col23, #T_755e4_row4_col24, #T_755e4_row4_col25, #T_755e4_row4_col26, #T_755e4_row4_col27, #T_755e4_row4_col28, #T_755e4_row4_col29, #T_755e4_row4_col30, #T_755e4_row4_col31, #T_755e4_row4_col32, #T_755e4_row4_col33, #T_755e4_row4_col34, #T_755e4_row5_col0, #T_755e4_row5_col1, #T_755e4_row5_col2, #T_755e4_row5_col3, #T_755e4_row5_col4, #T_755e4_row5_col5, #T_755e4_row5_col6, #T_755e4_row5_col7, #T_755e4_row5_col8, #T_755e4_row5_col9, #T_755e4_row5_col10, #T_755e4_row5_col11, #T_755e4_row5_col12, #T_755e4_row5_col13, #T_755e4_row5_col14, #T_755e4_row5_col15, #T_755e4_row5_col16, #T_755e4_row5_col17, #T_755e ...

# %%
# Select columns with correlations above threshold
collinear_features = [column for column in upper.columns if any(upper[column] > threshold)]
features_filtered = data.drop(columns = collinear_features)
print('The number of features that passed the collinearity threshold: ', features_filtered.shape[1])
features_best.append(features_filtered.columns.tolist())
# Out:
# The number of features that passed the collinearity threshold:  31

# %% [markdown]
# Using SelectFromModel with LinearSCV

# %%
lsvc = LinearSVC(C=0.1, penalty="l1", dual=False).fit(train, target)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(train)
X_selected_df = pd.DataFrame(X_new, columns=[train.columns[i] for i in range(len(train.columns)) if model.get_support()[i]])
features_best.append(X_selected_df.columns.tolist())

# %% [markdown]
# Using Recursive Feature Elimination (RFE) with Logistic Regression

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_features_max, step=10, verbose=5)
rfe_selector.fit(train, target)
rfe_support = rfe_selector.get_support()
rfe_feature = train.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 34 selected features

# %% [markdown]
# Using Variance Threshold

# %%
selector = VarianceThreshold(threshold=10)
np.shape(selector.fit_transform(data))
features_best.append(list(np.array(data.columns)[selector.get_support(indices=False)]))

# %%
#selecting the best features
features_best
# Out:
# [['Marital status',
#   'Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   'Nacionality',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Displaced',
#   'Educational special needs',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'Inflation rate',
#   'GDP',
#   'Target'],
#  ['Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   'Displaced',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'International',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (credited)',
#   'Curricular units 2nd sem (enrolled)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'Inflation rate'],
#  ['Application mode',
#   'Course',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Age at enrollment',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)']]

# %%
# The element is in at least one list of optimal features
main_cols_max = features_best[0]
for i in range(len(features_best)-1):
    main_cols_max = list(set(main_cols_max) | set(features_best[i+1]))
main_cols_max
# Out:
# ['GDP',
#  'Curricular units 2nd sem (enrolled)',
#  'Scholarship holder',
#  "Mother's occupation",
#  'Nacionality',
#  'Curricular units 1st sem (evaluations)',
#  'Application order',
#  'Course',
#  'Curricular units 2nd sem (without evaluations)',
#  'Marital status',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 2nd sem (credited)',
#  'Previous qualification',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (evaluations)',
#  'Application mode',
#  "Father's qualification",
#  "Mother's qualification",
#  'Curricular units 1st sem (enrolled)',
#  "Father's occupation",
#  'Curricular units 1st sem (grade)',
#  'Age at enrollment',
#  'Inflation rate',
#  'International',
#  'Debtor',
#  'Daytime/evening attendance',
#  'Educational special needs',
#  'Displaced',
#  'Target',
#  'Tuition fees up to date',
#  'Unemployment rate',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (without evaluations)',
#  'Gender',
#  'Curricular units 2nd sem (grade)']

# %%
len(main_cols_max)
# Out:
# 35

# %%
# The element is in all lists of optimal features
main_cols_min = features_best[0]
for i in range(len(features_best)-1):
    main_cols_min = list(set(main_cols_min).intersection(set(features_best[i+1])))
main_cols_min
# Out:
# ['Curricular units 1st sem (approved)',
#  "Father's qualification",
#  'Previous qualification',
#  "Mother's qualification",
#  "Mother's occupation",
#  'Application mode',
#  'Curricular units 1st sem (grade)',
#  'Age at enrollment',
#  'Course',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)']

# %%
# Most common items in all lists of optimal features
main_cols = []
main_cols_opt = {feature_name : 0 for feature_name in data.columns.tolist()}
for i in range(len(features_best)):
    for feature_name in features_best[i]:
        main_cols_opt[feature_name] += 1
df_main_cols_opt = pd.DataFrame.from_dict(main_cols_opt, orient='index', columns=['Target'])
df_main_cols_opt.sort_values(by=['Target'], ascending=False).head(num_features_opt)
# Out:
#                                                 Target
# Age at enrollment                                    3
# Father's qualification                               3
# Curricular units 2nd sem (grade)                     3
# Curricular units 1st sem (grade)                     3
# Curricular units 1st sem (approved)                  3
# Application mode                                     3
# Mother's occupation                                  3
# Curricular units 2nd sem (evaluations)               3
# Mother's qualification                               3
# Course                                               3
# Previous qualification                               3
# Curricular units 1st sem (credited)                  2
# Application order                                    2
# Curricular units 2nd sem (without evaluations)       2
# Curricular units 1st sem (without evaluations)       2
# Daytime/evening attendance                           2
# Curricular units 1st sem (evaluations)               2
# Curricular units 1st sem (enrolled)                  2
# Unemployment rate                                    2
# Scholarship holder                                   2
# Gender                                               2
# Debtor                                               2
# Inflation rate                                       2
# Displaced                                            2
# Father's occupation                                  2

# %%
main_cols = df_main_cols_opt.nlargest(num_features_opt, 'Target').index.tolist()
if not 'Target' in main_cols:
    main_cols.append('Target')
main_cols
# Out:
# ['Application mode',
#  'Course',
#  'Previous qualification',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  'Age at enrollment',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  'Application order',
#  'Daytime/evening attendance',
#  "Father's occupation",
#  'Displaced',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (without evaluations)',
#  'Unemployment rate',
#  'Target']

# %% [markdown]
# Preparing the model

# %%
from sklearn.model_selection import train_test_split

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
# Target
target_name = 'Target'
target0 = data['Target']
train0 = data[main_cols].drop([target_name], axis=1)

# %% [markdown]
# Scaling the Data

# %%
test_train_split_part = 0.2
cv_n_split = 3
random_state = 40

# For boosting model
train0b = train0.copy()

# Synthesis valid as "test" for selection models
trainb, testb, targetb, target_testb = train_test_split(train0b, target0, test_size=test_train_split_part, random_state=random_state)

# %%
# For models from Sklearn
scaler = MinMaxScaler()
train0 = pd.DataFrame(scaler.fit_transform(train0), columns = train0.columns)
scaler2 = RobustScaler()
train0 = pd.DataFrame(scaler2.fit_transform(train0), columns = train0.columns)

# %%
# Synthesis valid as test for selection models
train, test, target, target_test = train_test_split(train0, target0, test_size=test_train_split_part, random_state=random_state)

# %%
metrics_all = {1 : 'r2_score', 2: 'acc', 3 : 're', 4 : 'precision', 5: 'f1_score', 6:'recall'}
metrics_now = [1, 2, 3, 4,5,6]

# %%
# list of accuracy of all model
num_models = 6
acc_test = []
acc_all = np.empty((len(metrics_now)*2, 0)).tolist()
acc_all
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], []]

# %%
acc_all_pred = np.empty((len(metrics_now), 0)).tolist()
acc_all_pred
# Out:
# [[], [], [], [], [], []]

# %%
# Splitting train data for model tuning with cross-validation
from sklearn.model_selection import ShuffleSplit
test_train_split_part = 0.2
cv_n_split = 3
random_state = 40

cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)

# %%
def acc_d(y_meas, y_pred):
    # Relative error between predicted y_pred and measured y_meas values
    return mean_absolute_error(y_meas, y_pred)*len(y_meas)/sum(abs(y_meas))

# %%
def plot_cm(target_test, test_pred):
    # Building the confusion matrices
    
    def cm_calc(y_true, y_pred):
        cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
        cm_sum = np.sum(cm, axis=1, keepdims=True)
        cm_perc = cm / cm_sum.astype(float) * 100
        annot = np.empty_like(cm).astype(str)
        nrows, ncols = cm.shape
        for i in range(nrows):
            for j in range(ncols):
                c = cm[i, j]
                p = cm_perc[i, j]
                if i == j:
                    s = cm_sum[i]
                    annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                elif c == 0:
                    annot[i, j] = ''
                else:
                    annot[i, j] = '%.1f%%\n%d' % (p, c)
        cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
        cm.index.name = 'Actual'
        cm.columns.name = 'Predicted'
        return cm, annot

    
    # Building the confusion matrices
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 6), sharex=True)
    
    # Test data
    ax.set_title("for test (validation) data")
    cm1, annot1 = cm_calc(target_test, test_pred)
    sns.heatmap(cm1, cmap= "YlGnBu", annot=annot1, fmt='', ax=ax)
    
    fig.suptitle('CONFUSION MATRICES')
    plt.show()

# %%
def acc_metrics_calc(num,model,train,test,target,target_test):
    # The models selection stage
    # Calculation of accuracy of model by different metrics
    global acc_all

    ytest = model.predict(test).astype(int)
    if num != 17:
        print('target_test =', target_test[:5].values)
        print('ytest =', ytest[:5])

    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_test = round(r2_score(target_test, ytest) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_test = round(metrics.accuracy_score(target_test, ytest) * 100, 2)
        elif x == 3:
            #relative error criterion
            acc_test = round(acc_d(target_test, ytest) * 100, 2)
        elif x == 4:
            # precision score criterion
            precision_test = round(metrics.precision_score(target_test, ytest) * 100, 2)
        elif x == 5:
            # F1 score criterion
            f1_score_test = round(metrics.f1_score(target_test, ytest) * 100, 2)
        elif x == 6:
            # recall score criterion
            recall_test = round(metrics.recall_score(target_test, ytest) * 100, 2)
    
        
        print(metrics_all[x], '=', acc_test)
        acc_all[num_acc+1].append(acc_test) #test
        num_acc += 2
    
    #  Building the confusion matrices
    plot_cm(target_test, ytest)

# %%
def acc_metrics_calc_pred(num,model,name_model,train,test,target):
    # The prediction stage
    # Calculation of accuracy of model for all different metrics and creates of the main submission file for the best model (num=0)
    global acc_all_pred

    ytrain = model.predict(train).astype(int)
    ytest = model.predict(test).astype(int)

    print('**********')
    print(name_model)
    if num != 17:
        print('target = ', target[:15].values)
        print('ytrain = ', ytrain[:15])
        print('ytest =', ytest[:15])
    
    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_train = round(r2_score(target, ytrain) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_train = round(metrics.accuracy_score(target, ytrain) * 100, 2)
        
        elif x == 3:
            #relative error criterion
            acc_train = round(acc_d(target, ytrain) * 100, 2)
        elif x == 4:
            #precision score criterion
            precision = round(metrics.precision_score(target, ytrain) * 100, 2)
        elif x == 5:
            #F1 score criterion
            f1_score = round(metrics.f1_score(target, ytrain) * 100, 2)
        elif x == 6:
            #recall score criterion
            recall = round(metrics.recall_score(target, ytrain) * 100, 2)     


        print('acc of', metrics_all[x], 'for train =', acc_train)
        acc_all_pred[num_acc].append(acc_train) #train
        num_acc += 1
    
    # Save the submission file
    submission[target_name] = ytest
    submission.to_csv('submission_' + name_model + '.csv', index=False)

# %% [markdown]
# Tuning and Testing features

# %%
# Thanks to https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html#sphx-glr-auto-examples-model-selection-plot-learning-curve-py
def plot_learning_curve(estimator, title, X, y, cv=None, axes=None, ylim=None, 
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5), random_state=0):
    fig, axes = plt.subplots(2, 1, figsize=(20, 10))
    
    if axes is None:
        _, axes = plt.subplots(1, 2, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    axes[0].set_xlabel("Training examples")
    axes[0].set_ylabel("Score")

    cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)
    
    train_sizes, train_scores, test_scores, fit_times, _ = \
        learning_curve(estimator=estimator, X=X, y=y, cv=cv,
                       train_sizes=train_sizes,
                       return_times=True)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # Plot learning curve
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    axes[0].legend(loc="best")

    # Plot n_samples vs fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, 'o-')
    axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                         fit_times_mean + fit_times_std, alpha=0.1)
    axes[1].set_xlabel("Training examples")
    axes[1].set_ylabel("fit_times")
    axes[1].set_title("Scalability of the model")

    plt.show()
    return

# %% [markdown]
# Support Vector Machines

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(train, target)
print(svr_CV.best_params_)
acc_metrics_calc(1,svr_CV,train,test,target,target_test)
# Out:
# {'kernel': 'linear', 'tol': 0.001}
# target_test = [1 0 1 1 1]
# ytest = [1 0 1 1 1]
# r2_score = 64.36
# acc = 91.46
# re = 14.19
# precision = 14.19
# f1_score = 14.19
# recall = 14.19

# %%
# Building learning curve of model
plot_learning_curve(svr, "Support Vector Machines", train, target, cv=cv_train)

# %% [markdown]
# MLP Classifier

# %%
# %%time
# MLPClassifier

mlp = MLPClassifier()
param_grid = {'hidden_layer_sizes': [i for i in range(2,5)],
              'solver': ['sgd'],
              'learning_rate': ['adaptive'],
              'max_iter': [1000]
              }
mlp_GS = GridSearchCV(mlp, param_grid=param_grid, cv=cv_train, verbose=False)
mlp_GS.fit(train, target)
print(mlp_GS.best_params_)
acc_metrics_calc(3,mlp_GS,train,test,target,target_test)
# Out:
# {'hidden_layer_sizes': 3, 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
# target_test = [1 0 1 1 1]
# ytest = [1 0 1 1 1]
# r2_score = 59.76
# acc = 90.36
# re = 16.02
# precision = 16.02
# f1_score = 16.02
# recall = 16.02
# CPU times: total: 13.3 s
# Wall time: 16.8 s

# %%
# Building learning curve of model
plot_learning_curve(mlp, "MLP Classifier", train, target, cv=cv_train)

# %% [markdown]
# Stochastic Gradient Descent

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier(early_stopping=True)
param_grid = {'alpha': [0.035, 0.04, 0.45]}
sgd_CV = GridSearchCV(sgd, param_grid=param_grid, cv=cv_train, verbose=False)
sgd_CV.fit(train, target)
print(sgd_CV.best_params_)
acc_metrics_calc(4,sgd_CV,train,test,target,target_test)
# Out:
# {'alpha': 0.035}
# target_test = [1 0 1 1 1]
# ytest = [1 0 1 1 1]
# r2_score = 57.46
# acc = 89.81
# re = 16.93
# precision = 16.93
# f1_score = 16.93
# recall = 16.93

# %%
# Building learning curve of model
plot_learning_curve(sgd, "Stochastic Gradient Descent", train, target, cv=cv_train)

# %% [markdown]
# Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
param_grid = {'min_samples_leaf': [i for i in range(2,10)]}
decision_tree_CV = GridSearchCV(decision_tree, param_grid=param_grid, cv=cv_train, verbose=False)
decision_tree_CV.fit(train, target)
print(decision_tree_CV.best_params_)
acc_metrics_calc(5,decision_tree_CV,train,test,target,target_test)
# Out:
# {'min_samples_leaf': 5}
# target_test = [1 0 1 1 1]
# ytest = [1 0 1 1 1]
# r2_score = 37.92
# acc = 85.12
# re = 24.71
# precision = 24.71
# f1_score = 24.71
# recall = 24.71

# %%
# Building learning curve of model
plot_learning_curve(decision_tree_CV, "Decision Tree", train, target, cv=cv_train)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (2.0.0)
# Requirement already satisfied: numpy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.11.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost as xgb

# %%
# %%time
# XGBoost Classifier
xgb_clf = xgb.XGBClassifier(objective='reg:squarederror') 
parameters = {'n_estimators': [50, 60, 70, 80, 90], 
              'learning_rate': [0.09, 0.1, 0.15, 0.2],
              'max_depth': [3, 4, 5]}
xgb_reg = GridSearchCV(estimator=xgb_clf, param_grid=parameters, cv=cv_train).fit(train, target)
print("Best score: %0.3f" % xgb_reg.best_score_)
print("Best parameters set:", xgb_reg.best_params_)
acc_metrics_calc(7,xgb_reg,train,test,target,target_test)
# Out:
# Best score: 0.890
# Best parameters set: {'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 90}
# target_test = [1 0 1 1 1]
# ytest = [1 0 1 1 1]
# r2_score = 57.46
# acc = 89.81
# re = 16.93
# precision = 16.93
# f1_score = 16.93
# recall = 16.93
# CPU times: total: 1min 52s
# Wall time: 15.5 s

# %%
# Building learning curve of model
plot_learning_curve(xgb_clf, "XGBoost Classifier", train, target, cv=cv_train)

# %% [markdown]
# Neural Network with Keras

# %%
def build_nn(optimizer='adam'):

    # Initializing the NN
    nn = Sequential()

    # Adding the input layer and the first hidden layer of the NN
    nn.add(Dense(units=32, kernel_initializer='he_normal', activation='relu', input_shape=(len(train0.columns),)))
    # Adding the output layer
    nn.add(Dense(units=1, kernel_initializer='he_normal', activation='sigmoid'))

    # Compiling the NN
    nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return nn

Xtrain, Xval, Ztrain, Zval = train_test_split(train, target, test_size=test_train_split_part, random_state=random_state)
nn_model = build_nn(optimizers.Adam(lr=0.0001))
nn_model.fit(Xtrain, Ztrain, batch_size=16, epochs=100, validation_data=(Xval, Zval))
acc_metrics_calc(17,nn_model,train,test,target,target_test)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 146/146 [==============================] - 1s 3ms/step - loss: 0.5583 - accuracy: 0.7236 - val_loss: 0.4290 - val_accuracy: 0.8210
# Epoch 2/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8635 - val_loss: 0.3580 - val_accuracy: 0.8520
# Epoch 3/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.3141 - accuracy: 0.8799 - val_loss: 0.3353 - val_accuracy: 0.8554
# Epoch 4/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2901 - accuracy: 0.8907 - val_loss: 0.3248 - val_accuracy: 0.8675
# Epoch 5/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2762 - accuracy: 0.8954 - val_loss: 0.3205 - val_accuracy: 0.8709
# Epoch 6/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2681 - accuracy: 0.8980 - val_loss: 0.3164 - val_accuracy: 0.8744
# Epoch 7/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.9040 - val_loss: 0.3137 - val_accuracy: 0.8795
# Epoch 8/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2570 - accuracy: 0.9044 - val_loss: 0.3119 - val_accuracy: 0.8761
# Epoch 9/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2523 - accuracy: 0.9062 - val_loss: 0.3117 - val_accuracy: 0.8744
# Epoch 10/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2480 - accuracy: 0.9074 - val_loss: 0.3106 - val_accuracy: 0.8778
# Epoch 11/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9070 - val_loss: 0.3143 - val_accuracy: 0.8692
# Epoch 12/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.9092 - val_loss: 0.3116 - val_accuracy: 0.8778
# Epoch 13/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2396 - accuracy: 0.9118 - val_loss: 0.3135 - val_accuracy: 0.8830
# Epoch 14/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2371 - accuracy: 0.9105 - val_loss: 0.3116 - val_accuracy: 0.8761
# Epoch 15/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9079 - val_loss: 0.3126 - val_accuracy: 0.8812
# Epoch 16/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.9100 - val_loss: 0.3123 - val_accuracy: 0.8847
# Epoch 17/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.9126 - val_loss: 0.3131 - val_accuracy: 0.8778
# Epoch 18/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9105 - val_loss: 0.3137 - val_accuracy: 0.8830
# Epoch 19/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2256 - accuracy: 0.9148 - val_loss: 0.3173 - val_accuracy: 0.8812
# Epoch 20/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2256 - accuracy: 0.9122 - val_loss: 0.3197 - val_accuracy: 0.8692
# Epoch 21/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2230 - accuracy: 0.9156 - val_loss: 0.3199 - val_accuracy: 0.8761
# Epoch 22/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2221 - accuracy: 0.9156 - val_loss: 0.3196 - val_accuracy: 0.8778
# Epoch 23/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.9139 - val_loss: 0.3229 - val_accuracy: 0.8812
# Epoch 24/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9156 - val_loss: 0.3211 - val_accuracy: 0.8847
# Epoch 25/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2182 - accuracy: 0.9143 - val_loss: 0.3222 - val_accuracy: 0.8795
# Epoch 26/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2163 - accuracy: 0.9169 - val_loss: 0.3272 - val_accuracy: 0.8744
# Epoch 27/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2146 - accuracy: 0.9191 - val_loss: 0.3250 - val_accuracy: 0.8778
# Epoch 28/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2141 - accuracy: 0.9173 - val_loss: 0.3255 - val_accuracy: 0.8761
# Epoch 29/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2125 - accuracy: 0.9191 - val_loss: 0.3253 - val_accuracy: 0.8761
# Epoch 30/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2122 - accuracy: 0.9186 - val_loss: 0.3255 - val_accuracy: 0.8778
# Epoch 31/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2111 - accuracy: 0.9191 - val_loss: 0.3319 - val_accuracy: 0.8726
# Epoch 32/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2099 - accuracy: 0.9208 - val_loss: 0.3300 - val_accuracy: 0.8778
# Epoch 33/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2094 - accuracy: 0.9221 - val_loss: 0.3290 - val_accuracy: 0.8795
# Epoch 34/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2078 - accuracy: 0.9212 - val_loss: 0.3315 - val_accuracy: 0.8761
# Epoch 35/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 0.9195 - val_loss: 0.3336 - val_accuracy: 0.8761
# Epoch 36/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2052 - accuracy: 0.9208 - val_loss: 0.3389 - val_accuracy: 0.8709
# Epoch 37/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2055 - accuracy: 0.9238 - val_loss: 0.3343 - val_accuracy: 0.8761
# Epoch 38/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2037 - accuracy: 0.9208 - val_loss: 0.3372 - val_accuracy: 0.8692
# Epoch 39/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2036 - accuracy: 0.9247 - val_loss: 0.3372 - val_accuracy: 0.8761
# Epoch 40/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2016 - accuracy: 0.9234 - val_loss: 0.3386 - val_accuracy: 0.8761
# Epoch 41/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.2011 - accuracy: 0.9247 - val_loss: 0.3345 - val_accuracy: 0.8795
# Epoch 42/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1997 - accuracy: 0.9242 - val_loss: 0.3396 - val_accuracy: 0.8744
# Epoch 43/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1983 - accuracy: 0.9238 - val_loss: 0.3384 - val_accuracy: 0.8726
# Epoch 44/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1977 - accuracy: 0.9229 - val_loss: 0.3376 - val_accuracy: 0.8744
# Epoch 45/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.9268 - val_loss: 0.3426 - val_accuracy: 0.8744
# Epoch 46/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1963 - accuracy: 0.9260 - val_loss: 0.3432 - val_accuracy: 0.8726
# Epoch 47/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1965 - accuracy: 0.9260 - val_loss: 0.3418 - val_accuracy: 0.8795
# Epoch 48/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.9264 - val_loss: 0.3414 - val_accuracy: 0.8744
# Epoch 49/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9264 - val_loss: 0.3428 - val_accuracy: 0.8761
# Epoch 50/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.9251 - val_loss: 0.3461 - val_accuracy: 0.8761
# Epoch 51/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 0.9272 - val_loss: 0.3467 - val_accuracy: 0.8744
# Epoch 52/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1925 - accuracy: 0.9264 - val_loss: 0.3447 - val_accuracy: 0.8744
# Epoch 53/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9272 - val_loss: 0.3435 - val_accuracy: 0.8795
# Epoch 54/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.9255 - val_loss: 0.3514 - val_accuracy: 0.8726
# Epoch 55/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1905 - accuracy: 0.9285 - val_loss: 0.3513 - val_accuracy: 0.8726
# Epoch 56/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9272 - val_loss: 0.3466 - val_accuracy: 0.8761
# Epoch 57/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1882 - accuracy: 0.9268 - val_loss: 0.3498 - val_accuracy: 0.8761
# Epoch 58/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1877 - accuracy: 0.9272 - val_loss: 0.3491 - val_accuracy: 0.8726
# Epoch 59/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.9242 - val_loss: 0.3516 - val_accuracy: 0.8709
# Epoch 60/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1869 - accuracy: 0.9268 - val_loss: 0.3520 - val_accuracy: 0.8744
# Epoch 61/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1852 - accuracy: 0.9303 - val_loss: 0.3534 - val_accuracy: 0.8761
# Epoch 62/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.9260 - val_loss: 0.3557 - val_accuracy: 0.8744
# Epoch 63/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1840 - accuracy: 0.9320 - val_loss: 0.3607 - val_accuracy: 0.8761
# Epoch 64/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1840 - accuracy: 0.9294 - val_loss: 0.3536 - val_accuracy: 0.8761
# Epoch 65/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1837 - accuracy: 0.9264 - val_loss: 0.3558 - val_accuracy: 0.8726
# Epoch 66/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1818 - accuracy: 0.9285 - val_loss: 0.3543 - val_accuracy: 0.8761
# Epoch 67/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1830 - accuracy: 0.9281 - val_loss: 0.3571 - val_accuracy: 0.8761
# Epoch 68/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1816 - accuracy: 0.9307 - val_loss: 0.3559 - val_accuracy: 0.8778
# Epoch 69/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1803 - accuracy: 0.9303 - val_loss: 0.3709 - val_accuracy: 0.8726
# Epoch 70/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.9290 - val_loss: 0.3589 - val_accuracy: 0.8744
# Epoch 71/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1795 - accuracy: 0.9298 - val_loss: 0.3570 - val_accuracy: 0.8778
# Epoch 72/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1788 - accuracy: 0.9320 - val_loss: 0.3602 - val_accuracy: 0.8692
# Epoch 73/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1794 - accuracy: 0.9316 - val_loss: 0.3622 - val_accuracy: 0.8761
# Epoch 74/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1781 - accuracy: 0.9316 - val_loss: 0.3594 - val_accuracy: 0.8795
# Epoch 75/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1763 - accuracy: 0.9324 - val_loss: 0.3776 - val_accuracy: 0.8692
# Epoch 76/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1792 - accuracy: 0.9316 - val_loss: 0.3638 - val_accuracy: 0.8709
# Epoch 77/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9337 - val_loss: 0.3657 - val_accuracy: 0.8726
# Epoch 78/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9333 - val_loss: 0.3674 - val_accuracy: 0.8744
# Epoch 79/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1776 - accuracy: 0.9294 - val_loss: 0.3715 - val_accuracy: 0.8726
# Epoch 80/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1750 - accuracy: 0.9350 - val_loss: 0.3662 - val_accuracy: 0.8761
# Epoch 81/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 0.9346 - val_loss: 0.3718 - val_accuracy: 0.8709
# Epoch 82/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.9359 - val_loss: 0.3753 - val_accuracy: 0.8675
# Epoch 83/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9341 - val_loss: 0.3692 - val_accuracy: 0.8726
# Epoch 84/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1727 - accuracy: 0.9346 - val_loss: 0.3787 - val_accuracy: 0.8726
# Epoch 85/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1722 - accuracy: 0.9337 - val_loss: 0.3713 - val_accuracy: 0.8744
# Epoch 86/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9350 - val_loss: 0.3693 - val_accuracy: 0.8744
# Epoch 87/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1701 - accuracy: 0.9363 - val_loss: 0.3695 - val_accuracy: 0.8744
# Epoch 88/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9354 - val_loss: 0.3744 - val_accuracy: 0.8726
# Epoch 89/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1699 - accuracy: 0.9346 - val_loss: 0.3710 - val_accuracy: 0.8778
# Epoch 90/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1688 - accuracy: 0.9337 - val_loss: 0.3713 - val_accuracy: 0.8778
# Epoch 91/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1694 - accuracy: 0.9354 - val_loss: 0.3758 - val_accuracy: 0.8709
# Epoch 92/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1683 - accuracy: 0.9359 - val_loss: 0.3752 - val_accuracy: 0.8744
# Epoch 93/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1685 - accuracy: 0.9346 - val_loss: 0.3790 - val_accuracy: 0.8726
# Epoch 94/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1686 - accuracy: 0.9354 - val_loss: 0.3757 - val_accuracy: 0.8761
# Epoch 95/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9350 - val_loss: 0.3783 - val_accuracy: 0.8744
# Epoch 96/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1668 - accuracy: 0.9354 - val_loss: 0.3774 - val_accuracy: 0.8726
# Epoch 97/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9359 - val_loss: 0.3779 - val_accuracy: 0.8726
# Epoch 98/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1649 - accuracy: 0.9359 - val_loss: 0.3830 - val_accuracy: 0.8692
# Epoch 99/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9350 - val_loss: 0.3787 - val_accuracy: 0.8726
# Epoch 100/100
# 146/146 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9350 - val_loss: 0.3804 - val_accuracy: 0.8726
# 23/23 [==============================] - 0s 942us/step
# r2_score = -151.21
# acc = 39.81
# re = 100.0
# precision = 100.0
# f1_score = 100.0
# recall = 100.0

# %% [markdown]
# Gaussian Process

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
print(gpc_CV.best_params_)
acc_metrics_calc(18,gpc_CV,train,test,target,target_test)
# Out:
# {'max_iter_predict': 70, 'n_restarts_optimizer': 2, 'warm_start': False}
# target_test = [1 0 1 1 1]
# ytest = [1 0 1 1 1]
# r2_score = 57.46
# acc = 89.81
# re = 16.93
# precision = 16.93
# f1_score = 16.93
# recall = 16.93

# %%
# Building learning curve of model
plot_learning_curve(gpc, "Gaussian Process Classification", train, target, cv=cv_train)

# %% [markdown]
# Model Evaluation

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines','MLP Classifier', 'Stochastic Gradient Decent', 'Decision Tree Classifier','XGB Classifier',
              'NN model', 'Gaussian Process Classification'  ]})

# %%
for x in metrics_now:
    xs = metrics_all[x]
    models[xs + '_test'] = acc_all[(x-1)*2+1]

# %%
print('Prediction accuracy for models')
ms = metrics_all[metrics_now[1]] # the first from metrics
models[['Model',  ms + '_test']].sort_values(by=[(ms + '_test')], ascending=False)
# Out:
# Prediction accuracy for models
#                              Model  acc_test
# 0          Support Vector Machines     91.46
# 1                   MLP Classifier     90.36
# 2       Stochastic Gradient Decent     89.81
# 4                   XGB Classifier     89.81
# 6  Gaussian Process Classification     89.81
# 3         Decision Tree Classifier     85.12
# 5                         NN model     39.81

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
for x in metrics_now:   
    # Plot
    xs = metrics_all[x]
    xs_test = metrics_all[x] + '_test'
    plt.figure(figsize=[15,6])
    xx = models['Model']
    plt.tick_params(labelsize=14)
    plt.plot(xx, models[xs_test], label = xs_test)
    plt.legend()
    plt.title(str(xs) + ' criterion for ' + str(num_models) + ' models for train and test datasets')
    plt.xlabel('Models')
    plt.ylabel(xs + ', %')
    plt.xticks(xx, rotation='vertical')
    plt.show()

# %% [markdown]
# PLotting the Decision Boundary

# %%
X_train, X_test, y_train, y_test = train_test_split(
        train, target, test_size=0.2, random_state=3)

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=40, test_size=0.2, train_size=None),
#              estimator=SVC(),
#              param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                          'tol': [0.001]},
#              verbose=False)

# %%
# Make predictions using the testing set
svr_pred = svr_CV.predict(X_test)

# %%
#Using two features in the data set for plotting possibility. We can take any 2
svr_X_train = X_train.iloc[:, [2, 10]]
svr_y_train= y_train

# %%
svr_X_train.head()
# Out:
#       Previous qualification  Curricular units 2nd sem (grade)
# 178                     0.00                             -4.14
# 1850                    0.00                              0.53
# 457                     0.00                              0.06
# 285                     0.00                              0.06
# 3091                    0.81                              0.09

# %%
h = .02  # step size in the mesh

svr_CV.fit(svr_X_train, svr_y_train)

svr_X = X_test.iloc[:, [2,3]]
svr_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %% [markdown]
# Gaussian Process decision Boundary

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=40, test_size=0.2, train_size=None),
#              estimator=GaussianProcessClassifier(),
#              param_grid={'max_iter_predict': [70, 80, 90],
#                          'n_restarts_optimizer': range(2, 4),
#                          'warm_start': [False]},
#              verbose=False)

# %%
# Make predictions using the testing set
gaus_pred = gpc_CV.predict(X_test)

# %%
#Using two features in the data set for plotting possibility. We can take any 2
gaus_X_train = X_train.iloc[:, [2, 10]]
gaus_y_train= y_train

# %%
h = .02  # step size in the mesh

gpc_CV.fit(gaus_X_train, gaus_y_train)

gaus_X = X_test.iloc[:, [2,3]]
gaus_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Gaussian Process")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Gaussian Process")

plt.show()

# %%
sp = time.time()
time_taken = sp-st
print('This project took', time_taken, 'seconds to execute')
# Out:
# This project took 360.81216835975647 seconds to execute

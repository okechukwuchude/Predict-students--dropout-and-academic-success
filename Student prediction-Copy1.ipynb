# %%
import numpy as np
import pandas as pd
import ydata_profiling as pp
import math
import random
import seaborn as sns
import matplotlib.pyplot as plt
import time 

st = time.time()

# %matplotlib inline

# %%
# preprocessing
import sklearn
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score, confusion_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel, SelectKBest, RFE, chi2
from sklearn.model_selection import learning_curve

# models
from sklearn.linear_model import LogisticRegression, Perceptron, RidgeClassifier, SGDClassifier, LassoCV
from sklearn.svm import SVC, LinearSVC, SVR
from sklearn.ensemble import RandomForestClassifier 
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# NN models
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
#from keras.wrappers.scikit_learn import KerasClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\okechukwu chude\Documents\MOdeling and optimisation\Predict students' dropout and success\Predict-students--dropout-and-academic-success\dataset.csv")

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
#
# [3 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
#  9   Mother's occupation                             4424 non-null   int64
#  10  Father's occupation                             4424 non-null   int64
#  11  Displaced                                       4424 non-null   int64
#  12  Educational special needs                       4424 non-null   int64
#  13  Debtor                                          4424 non-null   int64
#  14  Tuition fees up to date                         4424 non-null   int64
#  15  Gender                                          4424 non-null   int64
#  16  Scholarship holder                              4424 non-null   int64
#  17  Age at enrollment                               4424 non-null   int64
#  18  International                                   4424 non-null   int64
#  19  Curricular units 1st sem (credited)             4424 non-null   int64
#  20  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  21  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  22  Curricular units 1st sem (approved)             4424 non-null   int64
#  23  Curricular units 1st sem (grade)                4424 non-null   float64
#  24  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  25  Curricular units 2nd sem (credited)             4424 non-null   int64
#  26  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  27  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  28  Curricular units 2nd sem (approved)             4424 non-null   int64
#  29  Curricular units 2nd sem (grade)                4424 non-null   float64
#  30  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  31  Unemployment rate                               4424 non-null   float64
#  32  Inflation rate                                  4424 non-null   float64
#  33  GDP                                             4424 non-null   float64
#  34  Target                                          4424 non-null   object
# dtypes: float64(5), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
#checking for missing values
data.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %%
data['Target'].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %% [markdown]
# Data Visualisation

# %%
#pp.ProfileReport(data)

# %%
#Dropping rows for enrolled students as this does not indicate the future outcome
data = data.drop(data[data['Target'] == 'Enrolled'].index)

# %%
label_encoder = LabelEncoder()

# Apply label encoding to non-numerical columns
columns_to_encode = ['Target']
for column in columns_to_encode:
    data[column] = label_encoder.fit_transform(data[column])

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
#for i in data.columns: 
 #   sns.countplot(x = i, data = data)
  #  plt.show()

# %%
# Create a heat map
correlation_matrix = data.corr()

# Plot the heatmap
plt.figure(figsize=(26, 12))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# %%
train = data.copy()
target = train.pop('Target')
train.head(2)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
#
#    Inflation rate   GDP
# 0             1.4  1.74
# 1            -0.3  0.79
#
# [2 rows x 34 columns]

# %% [markdown]
# Feature Selection

# %%
num_features_opt = 25   # the number of features that we need to choose as a result
num_features_max = 35  
features_best = []

# %% [markdown]
# Uisng Pearson Correlation

# %%
# Threshold for removing correlated variables
threshold = 0.9

def highlight(value):
    if value > threshold:
        style = 'background-color: pink'
    else:
        style = 'background-color: palegreen'
    return style

# Absolute value correlation matrix
corr_matrix = data.corr().abs().round(2)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
upper.style.format("{:.2f}").applymap(highlight)
# Out:
# <style type="text/css">
# #T_eb77b_row0_col0, #T_eb77b_row0_col1, #T_eb77b_row0_col2, #T_eb77b_row0_col3, #T_eb77b_row0_col4, #T_eb77b_row0_col5, #T_eb77b_row0_col6, #T_eb77b_row0_col7, #T_eb77b_row0_col8, #T_eb77b_row0_col9, #T_eb77b_row0_col10, #T_eb77b_row0_col11, #T_eb77b_row0_col12, #T_eb77b_row0_col13, #T_eb77b_row0_col14, #T_eb77b_row0_col15, #T_eb77b_row0_col16, #T_eb77b_row0_col17, #T_eb77b_row0_col18, #T_eb77b_row0_col19, #T_eb77b_row0_col20, #T_eb77b_row0_col21, #T_eb77b_row0_col22, #T_eb77b_row0_col23, #T_eb77b_row0_col24, #T_eb77b_row0_col25, #T_eb77b_row0_col26, #T_eb77b_row0_col27, #T_eb77b_row0_col28, #T_eb77b_row0_col29, #T_eb77b_row0_col30, #T_eb77b_row0_col31, #T_eb77b_row0_col32, #T_eb77b_row0_col33, #T_eb77b_row0_col34, #T_eb77b_row1_col0, #T_eb77b_row1_col1, #T_eb77b_row1_col2, #T_eb77b_row1_col3, #T_eb77b_row1_col4, #T_eb77b_row1_col5, #T_eb77b_row1_col6, #T_eb77b_row1_col7, #T_eb77b_row1_col8, #T_eb77b_row1_col9, #T_eb77b_row1_col10, #T_eb77b_row1_col11, #T_eb77b_row1_col12, #T_eb77b_row1_col13, #T_eb77b_row1_col14, #T_eb77b_row1_col15, #T_eb77b_row1_col16, #T_eb77b_row1_col17, #T_eb77b_row1_col18, #T_eb77b_row1_col19, #T_eb77b_row1_col20, #T_eb77b_row1_col21, #T_eb77b_row1_col22, #T_eb77b_row1_col23, #T_eb77b_row1_col24, #T_eb77b_row1_col25, #T_eb77b_row1_col26, #T_eb77b_row1_col27, #T_eb77b_row1_col28, #T_eb77b_row1_col29, #T_eb77b_row1_col30, #T_eb77b_row1_col31, #T_eb77b_row1_col32, #T_eb77b_row1_col33, #T_eb77b_row1_col34, #T_eb77b_row2_col0, #T_eb77b_row2_col1, #T_eb77b_row2_col2, #T_eb77b_row2_col3, #T_eb77b_row2_col4, #T_eb77b_row2_col5, #T_eb77b_row2_col6, #T_eb77b_row2_col7, #T_eb77b_row2_col8, #T_eb77b_row2_col9, #T_eb77b_row2_col10, #T_eb77b_row2_col11, #T_eb77b_row2_col12, #T_eb77b_row2_col13, #T_eb77b_row2_col14, #T_eb77b_row2_col15, #T_eb77b_row2_col16, #T_eb77b_row2_col17, #T_eb77b_row2_col18, #T_eb77b_row2_col19, #T_eb77b_row2_col20, #T_eb77b_row2_col21, #T_eb77b_row2_col22, #T_eb77b_row2_col23, #T_eb77b_row2_col24, #T_eb77b_row2_col25, #T_eb77b_row2_col26, #T_eb77b_row2_col27, #T_eb77b_row2_col28, #T_eb77b_row2_col29, #T_eb77b_row2_col30, #T_eb77b_row2_col31, #T_eb77b_row2_col32, #T_eb77b_row2_col33, #T_eb77b_row2_col34, #T_eb77b_row3_col0, #T_eb77b_row3_col1, #T_eb77b_row3_col2, #T_eb77b_row3_col3, #T_eb77b_row3_col4, #T_eb77b_row3_col5, #T_eb77b_row3_col6, #T_eb77b_row3_col7, #T_eb77b_row3_col8, #T_eb77b_row3_col9, #T_eb77b_row3_col10, #T_eb77b_row3_col11, #T_eb77b_row3_col12, #T_eb77b_row3_col13, #T_eb77b_row3_col14, #T_eb77b_row3_col15, #T_eb77b_row3_col16, #T_eb77b_row3_col17, #T_eb77b_row3_col18, #T_eb77b_row3_col19, #T_eb77b_row3_col20, #T_eb77b_row3_col21, #T_eb77b_row3_col22, #T_eb77b_row3_col23, #T_eb77b_row3_col24, #T_eb77b_row3_col25, #T_eb77b_row3_col26, #T_eb77b_row3_col27, #T_eb77b_row3_col28, #T_eb77b_row3_col29, #T_eb77b_row3_col30, #T_eb77b_row3_col31, #T_eb77b_row3_col32, #T_eb77b_row3_col33, #T_eb77b_row3_col34, #T_eb77b_row4_col0, #T_eb77b_row4_col1, #T_eb77b_row4_col2, #T_eb77b_row4_col3, #T_eb77b_row4_col4, #T_eb77b_row4_col5, #T_eb77b_row4_col6, #T_eb77b_row4_col7, #T_eb77b_row4_col8, #T_eb77b_row4_col9, #T_eb77b_row4_col10, #T_eb77b_row4_col11, #T_eb77b_row4_col12, #T_eb77b_row4_col13, #T_eb77b_row4_col14, #T_eb77b_row4_col15, #T_eb77b_row4_col16, #T_eb77b_row4_col17, #T_eb77b_row4_col18, #T_eb77b_row4_col19, #T_eb77b_row4_col20, #T_eb77b_row4_col21, #T_eb77b_row4_col22, #T_eb77b_row4_col23, #T_eb77b_row4_col24, #T_eb77b_row4_col25, #T_eb77b_row4_col26, #T_eb77b_row4_col27, #T_eb77b_row4_col28, #T_eb77b_row4_col29, #T_eb77b_row4_col30, #T_eb77b_row4_col31, #T_eb77b_row4_col32, #T_eb77b_row4_col33, #T_eb77b_row4_col34, #T_eb77b_row5_col0, #T_eb77b_row5_col1, #T_eb77b_row5_col2, #T_eb77b_row5_col3, #T_eb77b_row5_col4, #T_eb77b_row5_col5, #T_eb77b_row5_col6, #T_eb77b_row5_col7, #T_eb77b_row5_col8, #T_eb77b_row5_col9, #T_eb77b_row5_col10, #T_eb77b_row5_col11, #T_eb77b_row5_col12, #T_eb77b_row5_col13, #T_eb77b_row5_col14, #T_eb77b_row5_col15, #T_eb77b_row5_col16, #T_eb77b_row5_col17, #T_eb77 ...

# %%
# Select columns with correlations above threshold
collinear_features = [column for column in upper.columns if any(upper[column] > threshold)]
features_filtered = data.drop(columns = collinear_features)
print('The number of features that passed the collinearity threshold: ', features_filtered.shape[1])
features_best.append(features_filtered.columns.tolist())
# Out:
# The number of features that passed the collinearity threshold:  31

# %% [markdown]
# Using SelectFromModel with LinearSCV

# %%
lsvc = LinearSVC(C=0.1, penalty="l1", dual=False).fit(train, target)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(train)
X_selected_df = pd.DataFrame(X_new, columns=[train.columns[i] for i in range(len(train.columns)) if model.get_support()[i]])
features_best.append(X_selected_df.columns.tolist())

# %% [markdown]
# Using Recursive Feature Elimination (RFE) with Logistic Regression

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_features_max, step=10, verbose=5)
rfe_selector.fit(train, target)
rfe_support = rfe_selector.get_support()
rfe_feature = train.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 34 selected features

# %% [markdown]
# Using Recursive Feature Elimination (RFE) with Random Forest

# %%
embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=200), threshold='1.25*median')
embeded_rf_selector.fit(train, target)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(n_estimators=200),
#                 threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = train.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 11 selected features

# %%
features_best.append(embeded_rf_feature)

# %% [markdown]
# Using Variance Threshold

# %%
selector = VarianceThreshold(threshold=10)
np.shape(selector.fit_transform(data))
features_best.append(list(np.array(data.columns)[selector.get_support(indices=False)]))

# %%
#selecting the best features
features_best
# Out:
# [['Marital status',
#   'Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   'Nacionality',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Displaced',
#   'Educational special needs',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'Inflation rate',
#   'GDP',
#   'Target'],
#  ['Marital status',
#   'Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Displaced',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'International',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (credited)',
#   'Curricular units 2nd sem (enrolled)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'GDP'],
#  ['Course',
#   "Father's occupation",
#   'Tuition fees up to date',
#   'Age at enrollment',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (enrolled)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (grade)'],
#  ['Application mode',
#   'Course',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Age at enrollment',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)']]

# %%
# The element is in at least one list of optimal features
main_cols_max = features_best[0]
for i in range(len(features_best)-1):
    main_cols_max = list(set(main_cols_max) | set(features_best[i+1]))
main_cols_max
# Out:
# ['Tuition fees up to date',
#  'GDP',
#  "Father's qualification",
#  "Father's occupation",
#  'Daytime/evening attendance',
#  "Mother's qualification",
#  'Curricular units 2nd sem (approved)',
#  'Application order',
#  'Educational special needs',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 1st sem (without evaluations)',
#  'Unemployment rate',
#  'Displaced',
#  'Curricular units 1st sem (evaluations)',
#  'Gender',
#  'Course',
#  'Scholarship holder',
#  'Curricular units 1st sem (grade)',
#  'Application mode',
#  'Debtor',
#  'Curricular units 2nd sem (without evaluations)',
#  'Target',
#  'Curricular units 1st sem (credited)',
#  'International',
#  'Curricular units 2nd sem (enrolled)',
#  'Nacionality',
#  "Mother's occupation",
#  'Inflation rate',
#  'Age at enrollment',
#  'Marital status',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (enrolled)',
#  'Previous qualification']

# %%
len(main_cols_max)
# Out:
# 35

# %%
# The element is in all lists of optimal features
main_cols_min = features_best[0]
for i in range(len(features_best)-1):
    main_cols_min = list(set(main_cols_min).intersection(set(features_best[i+1])))
main_cols_min
# Out:
# ['Course',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (grade)',
#  "Father's occupation",
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (evaluations)',
#  'Age at enrollment']

# %%
# Most common items in all lists of optimal features
main_cols = []
main_cols_opt = {feature_name : 0 for feature_name in data.columns.tolist()}
for i in range(len(features_best)):
    for feature_name in features_best[i]:
        main_cols_opt[feature_name] += 1
df_main_cols_opt = pd.DataFrame.from_dict(main_cols_opt, orient='index', columns=['Target'])
df_main_cols_opt.sort_values(by=['Target'], ascending=False).head(num_features_opt)
# Out:
#                                                 Target
# Age at enrollment                                    4
# Curricular units 1st sem (evaluations)               4
# Curricular units 1st sem (grade)                     4
# Curricular units 2nd sem (evaluations)               4
# Curricular units 2nd sem (grade)                     4
# Father's occupation                                  4
# Course                                               4
# Curricular units 1st sem (approved)                  4
# Mother's qualification                               3
# Father's qualification                               3
# Mother's occupation                                  3
# Previous qualification                               3
# Tuition fees up to date                              3
# Application mode                                     3
# Curricular units 2nd sem (without evaluations)       2
# Unemployment rate                                    2
# Curricular units 2nd sem (approved)                  2
# Curricular units 2nd sem (enrolled)                  2
# Curricular units 1st sem (without evaluations)       2
# GDP                                                  2
# Marital status                                       2
# Curricular units 1st sem (enrolled)                  2
# Curricular units 1st sem (credited)                  2
# Scholarship holder                                   2
# Gender                                               2

# %%
main_cols = df_main_cols_opt.nlargest(num_features_opt, 'Target').index.tolist()
if not 'Target' in main_cols:
    main_cols.append('Target')
main_cols
# Out:
# ['Course',
#  "Father's occupation",
#  'Age at enrollment',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  'Application mode',
#  'Previous qualification',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  'Tuition fees up to date',
#  'Marital status',
#  'Application order',
#  'Daytime/evening attendance',
#  'Displaced',
#  'Debtor',
#  'Gender',
#  'Scholarship holder',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (enrolled)',
#  'Target']

# %% [markdown]
# Preparing the model

# %%
from sklearn.model_selection import train_test_split

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
# Target
target_name = 'Target'
target0 = data['Target']
train0 = data[main_cols].drop([target_name], axis=1)

# %% [markdown]
# Splitting the data

# %%
from sklearn.model_selection import train_test_split
train,test,target,target_test = train_test_split(train0, target0, test_size = 0.3,random_state=42)

# %%
metrics_all = {1 : 'r2_score', 2: 'acc', 3 : 're', 4 : 'precision', 5: 'f1_score', 6:'recall'}
metrics_now = [1, 2, 3, 4,5,6]

# %%
# list of accuracy of all model - amount of metrics_now * 2 (train & test datasets)
num_models = 6
acc_train = []
acc_test = []
acc_all = np.empty((len(metrics_now)*2, 0)).tolist()
acc_all
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], []]

# %%
acc_all_pred = np.empty((len(metrics_now), 0)).tolist()
acc_all_pred
# Out:
# [[], [], [], [], [], []]

# %%
# Splitting train data for model tuning with cross-validation
from sklearn.model_selection import ShuffleSplit
test_train_split_part = 0.2
cv_n_split = 3
random_state = 40

cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)

# %%
def acc_d(y_meas, y_pred):
    # Relative error between predicted y_pred and measured y_meas values
    return mean_absolute_error(y_meas, y_pred)*len(y_meas)/sum(abs(y_meas))

# %%
def plot_cm(target_test, test_pred):
    # Building the confusion matrices
    
    def cm_calc(y_true, y_pred):
        cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
        cm_sum = np.sum(cm, axis=1, keepdims=True)
        cm_perc = cm / cm_sum.astype(float) * 100
        annot = np.empty_like(cm).astype(str)
        nrows, ncols = cm.shape
        for i in range(nrows):
            for j in range(ncols):
                c = cm[i, j]
                p = cm_perc[i, j]
                if i == j:
                    s = cm_sum[i]
                    annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                elif c == 0:
                    annot[i, j] = ''
                else:
                    annot[i, j] = '%.1f%%\n%d' % (p, c)
        cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
        cm.index.name = 'Actual'
        cm.columns.name = 'Predicted'
        return cm, annot

    
    # Building the confusion matrices
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 6), sharex=True)
    
    # Test data
    ax.set_title("for test (validation) data")
    cm1, annot1 = cm_calc(target_test, test_pred)
    sns.heatmap(cm1, cmap= "YlGnBu", annot=annot1, fmt='', ax=ax)
    
    fig.suptitle('CONFUSION MATRICES')
    plt.show()

# %%
def acc_metrics_calc(num,model,train,test,target,target_test):
    # The models selection stage
    # Calculation of accuracy of model by different metrics
    global acc_all

    ytest = model.predict(test).astype(int)
    if num != 17:
        print('target_test =', target_test[:5].values)
        print('ytest =', ytest[:5])

    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_test = round(r2_score(target_test, ytest) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_test = round(metrics.accuracy_score(target_test, ytest) * 100, 2)
        elif x == 3:
            #rmse criterion
            acc_test = round(acc_rmse(target_test, ytest) * 100, 2)
        elif x == 4:
            #relative error criterion
            acc_test = round(acc_d(target_test, ytest) * 100, 2)
        elif x == 5:
            # precision score criterion
            precision_test = round(metrics.precision_score(target_test, ytest) * 100, 2)
        elif x == 6:
            # F1 score criterion
            f1_score_test = round(metrics.f1_score(target_test, ytest) * 100, 2)
        elif x == 7:
            # recall score criterion
            recall_test = round(metrics.recall_score(target_test, ytest) * 100, 2)
    
        
        print('acc of', metrics_all[x], 'for test =', acc_test)
        acc_all[num_acc+1].append(acc_test) #test
        num_acc += 2
    
    #  Building the confusion matrices
    plot_cm(target_test, ytest)

# %%
def acc_metrics_calc_pred(num,model,name_model,train,test,target):
    # The prediction stage
    # Calculation of accuracy of model for all different metrics and creates of the main submission file for the best model (num=0)
    global acc_all_pred

    ytrain = model.predict(train).astype(int)
    ytest = model.predict(test).astype(int)

    print('**********')
    print(name_model)
    if num != 17:
        print('target = ', target[:15].values)
        print('ytrain = ', ytrain[:15])
        print('ytest =', ytest[:15])
    
    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_train = round(r2_score(target, ytrain) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_train = round(metrics.accuracy_score(target, ytrain) * 100, 2)
        elif x == 3:
            #rmse criterion
            acc_train = round(acc_rmse(target, ytrain) * 100, 2)
        elif x == 4:
            #relative error criterion
            acc_train = round(acc_d(target, ytrain) * 100, 2)
        elif x == 5:
            #precision score criterion
            precision = round(metrics.precision_score(target, ytrain) * 100, 2)
        elif x == 6:
            #F1 score criterion
            f1_score = round(metrics.f1_score(target, ytrain) * 100, 2)
        elif x == 7:
            #recall score criterion
            recall = round(metrics.recall_score(target, ytrain) * 100, 2)     


        print('acc of', metrics_all[x], 'for train =', acc_train)
        acc_all_pred[num_acc].append(acc_train) #train
        num_acc += 1
    
    # Save the submission file
    submission[target_name] = ytest
    submission.to_csv('submission_' + name_model + '.csv', index=False)

# %% [markdown]
# Tuning and Testing features

# %%
# Thanks to https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html#sphx-glr-auto-examples-model-selection-plot-learning-curve-py
def plot_learning_curve(estimator, title, X, y, cv=None, axes=None, ylim=None, 
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5), random_state=0):
    fig, axes = plt.subplots(2, 1, figsize=(20, 10))
    
    if axes is None:
        _, axes = plt.subplots(1, 2, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    axes[0].set_xlabel("Training examples")
    axes[0].set_ylabel("Score")

    cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)
    
    train_sizes, train_scores, test_scores, fit_times, _ = \
        learning_curve(estimator=estimator, X=X, y=y, cv=cv,
                       train_sizes=train_sizes,
                       return_times=True)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # Plot learning curve
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    axes[0].legend(loc="best")

    # Plot n_samples vs fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, 'o-')
    axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                         fit_times_mean + fit_times_std, alpha=0.1)
    axes[1].set_xlabel("Training examples")
    axes[1].set_ylabel("fit_times")
    axes[1].set_title("Scalability of the model")

    plt.show()
    return

# %% [markdown]
# Support Vector Machines

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(train, target)
print(svr_CV.best_params_)
acc_metrics_calc(1,svr_CV,train,test,target,target_test)
# Out:
# {'kernel': 'linear', 'tol': 0.001}
# target_test = [1 0 0 1 0]
# ytest = [0 0 0 1 0]
# acc of r2_score for test = 60.25
# acc of acc for test = 90.63
# acc of re for test = 30.6
# acc of precision for test = 15.11
# acc of f1_score for test = 15.11
# acc of recall for test = 15.11

# %%
# Building learning curve of model
plot_learning_curve(svr, "Support Vector Machines", train, target, cv=cv_train)

# %% [markdown]
# MLP Classifier

# %%
# %%time
# MLPClassifier

mlp = MLPClassifier()
param_grid = {'hidden_layer_sizes': [i for i in range(2,5)],
              'solver': ['sgd'],
              'learning_rate': ['adaptive'],
              'max_iter': [1000]
              }
mlp_GS = GridSearchCV(mlp, param_grid=param_grid, cv=cv_train, verbose=False)
mlp_GS.fit(train, target)
print(mlp_GS.best_params_)
acc_metrics_calc(3,mlp_GS,train,test,target,target_test)
# Out:
# {'hidden_layer_sizes': 3, 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
# target_test = [1 0 0 1 0]
# ytest = [1 1 1 1 1]
# acc of r2_score for test = -61.33
# acc of acc for test = 61.98
# acc of re for test = 61.66
# acc of precision for test = 61.33
# acc of f1_score for test = 61.33
# acc of recall for test = 61.33
# CPU times: total: 8.58 s
# Wall time: 10.4 s

# %%
# Building learning curve of model
plot_learning_curve(mlp, "MLP Classifier", train, target, cv=cv_train)

# %% [markdown]
# Stochastic Gradient Descent

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier(early_stopping=True)
param_grid = {'alpha': [0.035, 0.04, 0.45]}
sgd_CV = GridSearchCV(sgd, param_grid=param_grid, cv=cv_train, verbose=False)
sgd_CV.fit(train, target)
print(sgd_CV.best_params_)
acc_metrics_calc(4,sgd_CV,train,test,target,target_test)
# Out:
# {'alpha': 0.45}
# target_test = [1 0 0 1 0]
# ytest = [1 1 0 1 0]
# acc of r2_score for test = 32.58
# acc of acc for test = 84.11
# acc of re for test = 39.86
# acc of precision for test = 25.63
# acc of f1_score for test = 25.63
# acc of recall for test = 25.63

# %%
# Building learning curve of model
plot_learning_curve(sgd, "Stochastic Gradient Descent", train, target, cv=cv_train)

# %% [markdown]
# Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
param_grid = {'min_samples_leaf': [i for i in range(2,10)]}
decision_tree_CV = GridSearchCV(decision_tree, param_grid=param_grid, cv=cv_train, verbose=False)
decision_tree_CV.fit(train, target)
print(decision_tree_CV.best_params_)
acc_metrics_calc(5,decision_tree_CV,train,test,target,target_test)
# Out:
# {'min_samples_leaf': 9}
# target_test = [1 0 0 1 0]
# ytest = [0 1 0 1 0]
# acc of r2_score for test = 48.95
# acc of acc for test = 87.97
# acc of re for test = 34.68
# acc of precision for test = 19.41
# acc of f1_score for test = 19.41
# acc of recall for test = 19.41

# %%
# Building learning curve of model
plot_learning_curve(decision_tree_CV, "Decision Tree", train, target, cv=cv_train)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (2.0.0)
# Requirement already satisfied: numpy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.11.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost as xgb

# %%
# %%time
# XGBoost Classifier
xgb_clf = xgb.XGBClassifier(objective='reg:squarederror') 
parameters = {'n_estimators': [50, 60, 70, 80, 90], 
              'learning_rate': [0.09, 0.1, 0.15, 0.2],
              'max_depth': [3, 4, 5]}
xgb_reg = GridSearchCV(estimator=xgb_clf, param_grid=parameters, cv=cv_train).fit(train, target)
print("Best score: %0.3f" % xgb_reg.best_score_)
print("Best parameters set:", xgb_reg.best_params_)
acc_metrics_calc(7,xgb_reg,train,test,target,target_test)
# Out:
# Best score: 0.900
# Best parameters set: {'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 90}
# target_test = [1 0 0 1 0]
# ytest = [0 0 0 1 0]
# acc of r2_score for test = 54.41
# acc of acc for test = 89.26
# acc of re for test = 32.78
# acc of precision for test = 17.33
# acc of f1_score for test = 17.33
# acc of recall for test = 17.33
# CPU times: total: 1min 47s
# Wall time: 15.8 s

# %%
# Building learning curve of model
plot_learning_curve(xgb_clf, "XGBoost Classifier", train, target, cv=cv_train)

# %% [markdown]
# Neural Network with Keras

# %%
def build_nn(optimizer='adam'):

    # Initializing the NN
    nn = Sequential()

    # Adding the input layer and the first hidden layer of the NN
    nn.add(Dense(units=32, kernel_initializer='he_normal', activation='relu', input_shape=(len(train0.columns),)))
    # Adding the output layer
    nn.add(Dense(units=1, kernel_initializer='he_normal', activation='sigmoid'))

    # Compiling the NN
    nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return nn

Xtrain, Xval, Ztrain, Zval = train_test_split(train, target, test_size=test_train_split_part, random_state=random_state)
nn_model = build_nn(optimizers.Adam(lr=0.0001))
nn_model.fit(Xtrain, Ztrain, batch_size=16, epochs=100, validation_data=(Xval, Zval))
acc_metrics_calc(17,nn_model,train,test,target,target_test)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 127/127 [==============================] - 1s 3ms/step - loss: 1.1929 - accuracy: 0.5856 - val_loss: 0.5362 - val_accuracy: 0.7741
# Epoch 2/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.5323 - accuracy: 0.7746 - val_loss: 0.3894 - val_accuracy: 0.8369
# Epoch 3/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.4309 - accuracy: 0.8273 - val_loss: 0.3521 - val_accuracy: 0.8566
# Epoch 4/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8460 - val_loss: 0.3378 - val_accuracy: 0.8684
# Epoch 5/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.8553 - val_loss: 0.3372 - val_accuracy: 0.8703
# Epoch 6/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8519 - val_loss: 0.3318 - val_accuracy: 0.8723
# Epoch 7/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8681 - val_loss: 0.3263 - val_accuracy: 0.8703
# Epoch 8/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8656 - val_loss: 0.3100 - val_accuracy: 0.8762
# Epoch 9/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.8765 - val_loss: 0.3177 - val_accuracy: 0.8723
# Epoch 10/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3107 - accuracy: 0.8681 - val_loss: 0.3033 - val_accuracy: 0.8782
# Epoch 11/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.8750 - val_loss: 0.3087 - val_accuracy: 0.8821
# Epoch 12/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 0.8804 - val_loss: 0.2985 - val_accuracy: 0.8821
# Epoch 13/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3048 - accuracy: 0.8765 - val_loss: 0.2954 - val_accuracy: 0.8802
# Epoch 14/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2929 - accuracy: 0.8829 - val_loss: 0.2970 - val_accuracy: 0.8861
# Epoch 15/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2913 - accuracy: 0.8760 - val_loss: 0.2860 - val_accuracy: 0.8919
# Epoch 16/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2927 - accuracy: 0.8829 - val_loss: 0.3147 - val_accuracy: 0.8762
# Epoch 17/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.8839 - val_loss: 0.2984 - val_accuracy: 0.8880
# Epoch 18/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2840 - accuracy: 0.8868 - val_loss: 0.2832 - val_accuracy: 0.8900
# Epoch 19/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2864 - accuracy: 0.8858 - val_loss: 0.3019 - val_accuracy: 0.8841
# Epoch 20/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.8858 - val_loss: 0.2913 - val_accuracy: 0.8919
# Epoch 21/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2816 - accuracy: 0.8888 - val_loss: 0.2828 - val_accuracy: 0.8880
# Epoch 22/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.8888 - val_loss: 0.3049 - val_accuracy: 0.8821
# Epoch 23/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2738 - accuracy: 0.8917 - val_loss: 0.2859 - val_accuracy: 0.8821
# Epoch 24/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.8962 - val_loss: 0.2853 - val_accuracy: 0.8880
# Epoch 25/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2731 - accuracy: 0.8942 - val_loss: 0.2940 - val_accuracy: 0.8841
# Epoch 26/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2767 - accuracy: 0.8863 - val_loss: 0.2797 - val_accuracy: 0.8900
# Epoch 27/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.8922 - val_loss: 0.2820 - val_accuracy: 0.8841
# Epoch 28/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.8917 - val_loss: 0.2841 - val_accuracy: 0.8939
# Epoch 29/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.8971 - val_loss: 0.2993 - val_accuracy: 0.8959
# Epoch 30/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.8922 - val_loss: 0.2892 - val_accuracy: 0.8900
# Epoch 31/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2677 - accuracy: 0.8952 - val_loss: 0.2809 - val_accuracy: 0.8939
# Epoch 32/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2696 - accuracy: 0.8957 - val_loss: 0.3038 - val_accuracy: 0.8841
# Epoch 33/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2657 - accuracy: 0.8937 - val_loss: 0.2773 - val_accuracy: 0.8959
# Epoch 34/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.8952 - val_loss: 0.2893 - val_accuracy: 0.8998
# Epoch 35/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.8947 - val_loss: 0.2878 - val_accuracy: 0.8880
# Epoch 36/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.9011 - val_loss: 0.2816 - val_accuracy: 0.8919
# Epoch 37/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.8927 - val_loss: 0.2860 - val_accuracy: 0.8959
# Epoch 38/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.8957 - val_loss: 0.3240 - val_accuracy: 0.8802
# Epoch 39/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2636 - accuracy: 0.8967 - val_loss: 0.3014 - val_accuracy: 0.8959
# Epoch 40/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2614 - accuracy: 0.8942 - val_loss: 0.2795 - val_accuracy: 0.8939
# Epoch 41/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2589 - accuracy: 0.9035 - val_loss: 0.2895 - val_accuracy: 0.8919
# Epoch 42/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2591 - accuracy: 0.9026 - val_loss: 0.2905 - val_accuracy: 0.8900
# Epoch 43/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.9035 - val_loss: 0.2863 - val_accuracy: 0.8919
# Epoch 44/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 0.9011 - val_loss: 0.2984 - val_accuracy: 0.8978
# Epoch 45/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.8981 - val_loss: 0.2797 - val_accuracy: 0.9037
# Epoch 46/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2556 - accuracy: 0.8996 - val_loss: 0.3085 - val_accuracy: 0.8919
# Epoch 47/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.9035 - val_loss: 0.2893 - val_accuracy: 0.8998
# Epoch 48/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 0.9006 - val_loss: 0.2882 - val_accuracy: 0.8959
# Epoch 49/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.9040 - val_loss: 0.2830 - val_accuracy: 0.8959
# Epoch 50/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9031 - val_loss: 0.3108 - val_accuracy: 0.8919
# Epoch 51/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.9040 - val_loss: 0.3686 - val_accuracy: 0.8546
# Epoch 52/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.9080 - val_loss: 0.3002 - val_accuracy: 0.8880
# Epoch 53/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2519 - accuracy: 0.9001 - val_loss: 0.3426 - val_accuracy: 0.8684
# Epoch 54/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.9060 - val_loss: 0.2956 - val_accuracy: 0.8998
# Epoch 55/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2455 - accuracy: 0.8976 - val_loss: 0.2862 - val_accuracy: 0.9018
# Epoch 56/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.9050 - val_loss: 0.2975 - val_accuracy: 0.9018
# Epoch 57/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.9085 - val_loss: 0.3140 - val_accuracy: 0.8919
# Epoch 58/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.9011 - val_loss: 0.3140 - val_accuracy: 0.8959
# Epoch 59/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.9031 - val_loss: 0.3340 - val_accuracy: 0.8743
# Epoch 60/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.9035 - val_loss: 0.3051 - val_accuracy: 0.8900
# Epoch 61/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.9045 - val_loss: 0.2842 - val_accuracy: 0.9018
# Epoch 62/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.9065 - val_loss: 0.3023 - val_accuracy: 0.8900
# Epoch 63/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2469 - accuracy: 0.9065 - val_loss: 0.3096 - val_accuracy: 0.8919
# Epoch 64/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.9040 - val_loss: 0.3028 - val_accuracy: 0.8959
# Epoch 65/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.9050 - val_loss: 0.2931 - val_accuracy: 0.8978
# Epoch 66/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9085 - val_loss: 0.2859 - val_accuracy: 0.9037
# Epoch 67/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2419 - accuracy: 0.9040 - val_loss: 0.3310 - val_accuracy: 0.8802
# Epoch 68/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9070 - val_loss: 0.3011 - val_accuracy: 0.8939
# Epoch 69/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2453 - accuracy: 0.8991 - val_loss: 0.3184 - val_accuracy: 0.8802
# Epoch 70/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2452 - accuracy: 0.9035 - val_loss: 0.3102 - val_accuracy: 0.8919
# Epoch 71/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2368 - accuracy: 0.9094 - val_loss: 0.2962 - val_accuracy: 0.8998
# Epoch 72/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9090 - val_loss: 0.2984 - val_accuracy: 0.8959
# Epoch 73/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2357 - accuracy: 0.9040 - val_loss: 0.3022 - val_accuracy: 0.8959
# Epoch 74/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.9090 - val_loss: 0.3295 - val_accuracy: 0.8802
# Epoch 75/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2385 - accuracy: 0.9085 - val_loss: 0.3195 - val_accuracy: 0.8861
# Epoch 76/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.9075 - val_loss: 0.3022 - val_accuracy: 0.9018
# Epoch 77/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2309 - accuracy: 0.9119 - val_loss: 0.3192 - val_accuracy: 0.8861
# Epoch 78/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2329 - accuracy: 0.9085 - val_loss: 0.3330 - val_accuracy: 0.8841
# Epoch 79/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2329 - accuracy: 0.9070 - val_loss: 0.3089 - val_accuracy: 0.8939
# Epoch 80/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2369 - accuracy: 0.9055 - val_loss: 0.3103 - val_accuracy: 0.8978
# Epoch 81/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2305 - accuracy: 0.9104 - val_loss: 0.3284 - val_accuracy: 0.8939
# Epoch 82/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9085 - val_loss: 0.3031 - val_accuracy: 0.8959
# Epoch 83/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9104 - val_loss: 0.3162 - val_accuracy: 0.8978
# Epoch 84/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9065 - val_loss: 0.3161 - val_accuracy: 0.8998
# Epoch 85/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.9119 - val_loss: 0.3156 - val_accuracy: 0.8998
# Epoch 86/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2255 - accuracy: 0.9129 - val_loss: 0.3060 - val_accuracy: 0.8959
# Epoch 87/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2281 - accuracy: 0.9085 - val_loss: 0.3655 - val_accuracy: 0.8664
# Epoch 88/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9075 - val_loss: 0.3105 - val_accuracy: 0.8998
# Epoch 89/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.9085 - val_loss: 0.3188 - val_accuracy: 0.8978
# Epoch 90/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9109 - val_loss: 0.3219 - val_accuracy: 0.8919
# Epoch 91/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2242 - accuracy: 0.9129 - val_loss: 0.3184 - val_accuracy: 0.8998
# Epoch 92/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.9149 - val_loss: 0.3455 - val_accuracy: 0.8841
# Epoch 93/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2229 - accuracy: 0.9094 - val_loss: 0.3645 - val_accuracy: 0.8782
# Epoch 94/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2231 - accuracy: 0.9065 - val_loss: 0.3189 - val_accuracy: 0.8959
# Epoch 95/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.9158 - val_loss: 0.3190 - val_accuracy: 0.8939
# Epoch 96/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9139 - val_loss: 0.3323 - val_accuracy: 0.8900
# Epoch 97/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2220 - accuracy: 0.9094 - val_loss: 0.3204 - val_accuracy: 0.8978
# Epoch 98/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9094 - val_loss: 0.3584 - val_accuracy: 0.8821
# Epoch 99/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2259 - accuracy: 0.9085 - val_loss: 0.3476 - val_accuracy: 0.8841
# Epoch 100/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2168 - accuracy: 0.9144 - val_loss: 0.3531 - val_accuracy: 0.8841
# 35/35 [==============================] - 0s 1ms/step
# acc of r2_score for test = -162.65
# acc of acc for test = 38.11
# acc of re for test = 78.67
# acc of precision for test = 99.85
# acc of f1_score for test = 99.85
# acc of recall for test = 99.85

# %% [markdown]
# Gaussian Process

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
print(gpc_CV.best_params_)
acc_metrics_calc(18,gpc_CV,train,test,target,target_test)
# Out:
# {'max_iter_predict': 70, 'n_restarts_optimizer': 2, 'warm_start': False}
# target_test = [1 0 0 1 0]
# ytest = [0 1 0 1 0]
# acc of r2_score for test = 12.32
# acc of acc for test = 79.34
# acc of re for test = 45.45
# acc of precision for test = 33.33
# acc of f1_score for test = 33.33
# acc of recall for test = 33.33

# %%
# Building learning curve of model
plot_learning_curve(gpc, "Gaussian Process Classification", train, target, cv=cv_train)

# %% [markdown]
# Model Evaluation

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines','MLP Classifier', 'Stochastic Gradient Decent', 'Decision Tree Classifier','XGB Classifier',
              'NN model', 'Gaussian Process Classification'  ]})

# %%
for x in metrics_now:
    xs = metrics_all[x]
    models[xs + '_test'] = acc_all[(x-1)*2+1]
    if xs == "acc":
        models[xs + '_diff'] = models[xs + '_train'] - models[xs + '_test']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[194], line 3
#       1 for x in metrics_now:
#       2     xs = metrics_all[x]
# ----> 3     models[xs + '_test'] = acc_all[(x-1)*2+1]
#       4     if xs == "acc":
#       5         models[xs + '_diff'] = models[xs + '_train'] - models[xs + '_test']
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
#    4148         and not is_extension_array_dtype(value)
#    4149     ):
#    4150         # broadcast across multiple columns if necessary
#    4151         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4870, in DataFrame._sanitize_column(self, value)
#    4867     return _reindex_for_setitem(Series(value), self.index)
#    4869 if is_list_like(value):
# -> 4870     com.require_length_match(value, self.index)
#    4871 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (18) does not match length of index (7)

# %%
print('Prediction accuracy for models')
ms = metrics_all[metrics_now[1]] # the first from metrics
models[['Model', ms + '_train', ms + '_test', 'acc_diff']].sort_values(by=[(ms + '_test'), (ms + '_train')], ascending=False)

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
for x in metrics_now:   
    # Plot
    xs = metrics_all[x]
    xs_train = metrics_all[x] + '_train'
    xs_test = metrics_all[x] + '_test'
    plt.figure(figsize=[15,6])
    xx = models['Model']
    plt.tick_params(labelsize=14)
    plt.plot(xx, models[xs_train], label = xs_train)
    plt.plot(xx, models[xs_test], label = xs_test)
    plt.legend()
    plt.title(str(xs) + ' criterion for ' + str(num_models) + ' models for train and test datasets')
    plt.xlabel('Models')
    plt.ylabel(xs + ', %')
    plt.xticks(xx, rotation='vertical')
    plt.show()

# %% [markdown]
# Extension

# %%
# Split the data and targets into training/testing sets
X_train, X_test, y_train, y_test = train_test_split(
        train, target, test_size=0.2, random_state=3)

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(X_train, y_train)

# %%
print(svr_CV.best_params_)
acc_metrics_calc(1,svr_CV,train,test,target,target_test)

# %%
# Make predictions using the testing set
svr_pred = svr_CV.predict(X_test)

# %%
#Using two features in the data set for plotting possibility. We can take any 2
svr_X_train = X_train.iloc[:, [2, 10]]
svr_y_train= y_train

# %%
svr_X_train.head()

# %%
h = .02  # step size in the mesh

svr_CV.fit(svr_X_train, svr_y_train)

svr_X = X_test.iloc[:, [2,3]]
svr_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
sp = time.time()
time_taken = sp-st
print('This project took', time_taken, 'seconds to execute')

# %% [markdown]
# Cross Validation

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
print(gpc_CV.best_params_)
acc_metrics_calc(18,gpc_CV,X_train,X_test, y_train, y_test)

# %%
# Make predictions using the testing set
gaus_pred = gpc_CV.predict(X_test)

# %%
X_train

# %%
#Using two features in the data set for plotting possibility. We can take any 2
gaus_X_train = X_train.iloc[:, [2, 10]]
gaus_y_train= y_train

# %%
h = .02  # step size in the mesh

gpc_CV.fit(gaus_X_train, gaus_y_train)

gaus_X = X_test.iloc[:, [2,3]]
gaus_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

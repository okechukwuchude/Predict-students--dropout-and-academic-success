# %%
import numpy as np
import pandas as pd
import ydata_profiling as pp
import math
import random
import seaborn as sns
import matplotlib.pyplot as plt
import time 

st = time.time()

# %matplotlib inline

# %%
# preprocessing
import sklearn
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score, confusion_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel, SelectKBest, RFE, chi2
from sklearn.model_selection import learning_curve

# models
from sklearn.linear_model import LogisticRegression, Perceptron, RidgeClassifier, SGDClassifier, LassoCV
from sklearn.svm import SVC, LinearSVC, SVR
from sklearn.ensemble import RandomForestClassifier 
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# NN models
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
#from keras.wrappers.scikit_learn import KerasClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\okechukwu chude\Documents\MOdeling and optimisation\Predict students' dropout and success\Predict-students--dropout-and-academic-success\dataset.csv")

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
#
# [3 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
#  9   Mother's occupation                             4424 non-null   int64
#  10  Father's occupation                             4424 non-null   int64
#  11  Displaced                                       4424 non-null   int64
#  12  Educational special needs                       4424 non-null   int64
#  13  Debtor                                          4424 non-null   int64
#  14  Tuition fees up to date                         4424 non-null   int64
#  15  Gender                                          4424 non-null   int64
#  16  Scholarship holder                              4424 non-null   int64
#  17  Age at enrollment                               4424 non-null   int64
#  18  International                                   4424 non-null   int64
#  19  Curricular units 1st sem (credited)             4424 non-null   int64
#  20  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  21  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  22  Curricular units 1st sem (approved)             4424 non-null   int64
#  23  Curricular units 1st sem (grade)                4424 non-null   float64
#  24  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  25  Curricular units 2nd sem (credited)             4424 non-null   int64
#  26  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  27  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  28  Curricular units 2nd sem (approved)             4424 non-null   int64
#  29  Curricular units 2nd sem (grade)                4424 non-null   float64
#  30  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  31  Unemployment rate                               4424 non-null   float64
#  32  Inflation rate                                  4424 non-null   float64
#  33  GDP                                             4424 non-null   float64
#  34  Target                                          4424 non-null   object
# dtypes: float64(5), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
#checking for missing values
data.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %%
data['Target'].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %% [markdown]
# Data Visualisation

# %%
#pp.ProfileReport(data)

# %%
#Dropping rows for enrolled students as this does not indicate the future outcome
data = data.drop(data[data['Target'] == 'Enrolled'].index)

# %%
label_encoder = LabelEncoder()

# Apply label encoding to non-numerical columns
columns_to_encode = ['Target']
for column in columns_to_encode:
    data[column] = label_encoder.fit_transform(data[column])

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
#for i in data.columns: 
 #   sns.countplot(x = i, data = data)
  #  plt.show()

# %%
# Create a heat map
correlation_matrix = data.corr()

# Plot the heatmap
plt.figure(figsize=(26, 12))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# %%
train = data.copy()
target = train.pop('Target')
train.head(2)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
#
#    Inflation rate   GDP
# 0             1.4  1.74
# 1            -0.3  0.79
#
# [2 rows x 34 columns]

# %% [markdown]
# Feature Selection

# %%
num_features_opt = 25   # the number of features that we need to choose as a result
num_features_max = 35  
features_best = []

# %% [markdown]
# Uisng Pearson Correlation

# %%
# Threshold for removing correlated variables
threshold = 0.9

def highlight(value):
    if value > threshold:
        style = 'background-color: pink'
    else:
        style = 'background-color: palegreen'
    return style

# Absolute value correlation matrix
corr_matrix = data.corr().abs().round(2)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
upper.style.format("{:.2f}").applymap(highlight)
# Out:
# <style type="text/css">
# #T_eb77b_row0_col0, #T_eb77b_row0_col1, #T_eb77b_row0_col2, #T_eb77b_row0_col3, #T_eb77b_row0_col4, #T_eb77b_row0_col5, #T_eb77b_row0_col6, #T_eb77b_row0_col7, #T_eb77b_row0_col8, #T_eb77b_row0_col9, #T_eb77b_row0_col10, #T_eb77b_row0_col11, #T_eb77b_row0_col12, #T_eb77b_row0_col13, #T_eb77b_row0_col14, #T_eb77b_row0_col15, #T_eb77b_row0_col16, #T_eb77b_row0_col17, #T_eb77b_row0_col18, #T_eb77b_row0_col19, #T_eb77b_row0_col20, #T_eb77b_row0_col21, #T_eb77b_row0_col22, #T_eb77b_row0_col23, #T_eb77b_row0_col24, #T_eb77b_row0_col25, #T_eb77b_row0_col26, #T_eb77b_row0_col27, #T_eb77b_row0_col28, #T_eb77b_row0_col29, #T_eb77b_row0_col30, #T_eb77b_row0_col31, #T_eb77b_row0_col32, #T_eb77b_row0_col33, #T_eb77b_row0_col34, #T_eb77b_row1_col0, #T_eb77b_row1_col1, #T_eb77b_row1_col2, #T_eb77b_row1_col3, #T_eb77b_row1_col4, #T_eb77b_row1_col5, #T_eb77b_row1_col6, #T_eb77b_row1_col7, #T_eb77b_row1_col8, #T_eb77b_row1_col9, #T_eb77b_row1_col10, #T_eb77b_row1_col11, #T_eb77b_row1_col12, #T_eb77b_row1_col13, #T_eb77b_row1_col14, #T_eb77b_row1_col15, #T_eb77b_row1_col16, #T_eb77b_row1_col17, #T_eb77b_row1_col18, #T_eb77b_row1_col19, #T_eb77b_row1_col20, #T_eb77b_row1_col21, #T_eb77b_row1_col22, #T_eb77b_row1_col23, #T_eb77b_row1_col24, #T_eb77b_row1_col25, #T_eb77b_row1_col26, #T_eb77b_row1_col27, #T_eb77b_row1_col28, #T_eb77b_row1_col29, #T_eb77b_row1_col30, #T_eb77b_row1_col31, #T_eb77b_row1_col32, #T_eb77b_row1_col33, #T_eb77b_row1_col34, #T_eb77b_row2_col0, #T_eb77b_row2_col1, #T_eb77b_row2_col2, #T_eb77b_row2_col3, #T_eb77b_row2_col4, #T_eb77b_row2_col5, #T_eb77b_row2_col6, #T_eb77b_row2_col7, #T_eb77b_row2_col8, #T_eb77b_row2_col9, #T_eb77b_row2_col10, #T_eb77b_row2_col11, #T_eb77b_row2_col12, #T_eb77b_row2_col13, #T_eb77b_row2_col14, #T_eb77b_row2_col15, #T_eb77b_row2_col16, #T_eb77b_row2_col17, #T_eb77b_row2_col18, #T_eb77b_row2_col19, #T_eb77b_row2_col20, #T_eb77b_row2_col21, #T_eb77b_row2_col22, #T_eb77b_row2_col23, #T_eb77b_row2_col24, #T_eb77b_row2_col25, #T_eb77b_row2_col26, #T_eb77b_row2_col27, #T_eb77b_row2_col28, #T_eb77b_row2_col29, #T_eb77b_row2_col30, #T_eb77b_row2_col31, #T_eb77b_row2_col32, #T_eb77b_row2_col33, #T_eb77b_row2_col34, #T_eb77b_row3_col0, #T_eb77b_row3_col1, #T_eb77b_row3_col2, #T_eb77b_row3_col3, #T_eb77b_row3_col4, #T_eb77b_row3_col5, #T_eb77b_row3_col6, #T_eb77b_row3_col7, #T_eb77b_row3_col8, #T_eb77b_row3_col9, #T_eb77b_row3_col10, #T_eb77b_row3_col11, #T_eb77b_row3_col12, #T_eb77b_row3_col13, #T_eb77b_row3_col14, #T_eb77b_row3_col15, #T_eb77b_row3_col16, #T_eb77b_row3_col17, #T_eb77b_row3_col18, #T_eb77b_row3_col19, #T_eb77b_row3_col20, #T_eb77b_row3_col21, #T_eb77b_row3_col22, #T_eb77b_row3_col23, #T_eb77b_row3_col24, #T_eb77b_row3_col25, #T_eb77b_row3_col26, #T_eb77b_row3_col27, #T_eb77b_row3_col28, #T_eb77b_row3_col29, #T_eb77b_row3_col30, #T_eb77b_row3_col31, #T_eb77b_row3_col32, #T_eb77b_row3_col33, #T_eb77b_row3_col34, #T_eb77b_row4_col0, #T_eb77b_row4_col1, #T_eb77b_row4_col2, #T_eb77b_row4_col3, #T_eb77b_row4_col4, #T_eb77b_row4_col5, #T_eb77b_row4_col6, #T_eb77b_row4_col7, #T_eb77b_row4_col8, #T_eb77b_row4_col9, #T_eb77b_row4_col10, #T_eb77b_row4_col11, #T_eb77b_row4_col12, #T_eb77b_row4_col13, #T_eb77b_row4_col14, #T_eb77b_row4_col15, #T_eb77b_row4_col16, #T_eb77b_row4_col17, #T_eb77b_row4_col18, #T_eb77b_row4_col19, #T_eb77b_row4_col20, #T_eb77b_row4_col21, #T_eb77b_row4_col22, #T_eb77b_row4_col23, #T_eb77b_row4_col24, #T_eb77b_row4_col25, #T_eb77b_row4_col26, #T_eb77b_row4_col27, #T_eb77b_row4_col28, #T_eb77b_row4_col29, #T_eb77b_row4_col30, #T_eb77b_row4_col31, #T_eb77b_row4_col32, #T_eb77b_row4_col33, #T_eb77b_row4_col34, #T_eb77b_row5_col0, #T_eb77b_row5_col1, #T_eb77b_row5_col2, #T_eb77b_row5_col3, #T_eb77b_row5_col4, #T_eb77b_row5_col5, #T_eb77b_row5_col6, #T_eb77b_row5_col7, #T_eb77b_row5_col8, #T_eb77b_row5_col9, #T_eb77b_row5_col10, #T_eb77b_row5_col11, #T_eb77b_row5_col12, #T_eb77b_row5_col13, #T_eb77b_row5_col14, #T_eb77b_row5_col15, #T_eb77b_row5_col16, #T_eb77b_row5_col17, #T_eb77 ...

# %%
# Select columns with correlations above threshold
collinear_features = [column for column in upper.columns if any(upper[column] > threshold)]
features_filtered = data.drop(columns = collinear_features)
print('The number of features that passed the collinearity threshold: ', features_filtered.shape[1])
features_best.append(features_filtered.columns.tolist())
# Out:
# The number of features that passed the collinearity threshold:  31

# %% [markdown]
# Using SelectFromModel with LinearSCV

# %%
lsvc = LinearSVC(C=0.1, penalty="l1", dual=False).fit(train, target)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(train)
X_selected_df = pd.DataFrame(X_new, columns=[train.columns[i] for i in range(len(train.columns)) if model.get_support()[i]])
features_best.append(X_selected_df.columns.tolist())

# %% [markdown]
# Using Recursive Feature Elimination (RFE) with Logistic Regression

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_features_max, step=10, verbose=5)
rfe_selector.fit(train, target)
rfe_support = rfe_selector.get_support()
rfe_feature = train.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 34 selected features

# %% [markdown]
# Using Recursive Feature Elimination (RFE) with Random Forest

# %%
embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=200), threshold='1.25*median')
embeded_rf_selector.fit(train, target)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(n_estimators=200),
#                 threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = train.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 11 selected features

# %%
features_best.append(embeded_rf_feature)

# %% [markdown]
# Using Variance Threshold

# %%
selector = VarianceThreshold(threshold=10)
np.shape(selector.fit_transform(data))
features_best.append(list(np.array(data.columns)[selector.get_support(indices=False)]))

# %%
#selecting the best features
features_best
# Out:
# [['Marital status',
#   'Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   'Nacionality',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Displaced',
#   'Educational special needs',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'Inflation rate',
#   'GDP',
#   'Target'],
#  ['Marital status',
#   'Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Displaced',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'International',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (credited)',
#   'Curricular units 2nd sem (enrolled)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'GDP'],
#  ['Course',
#   "Father's occupation",
#   'Tuition fees up to date',
#   'Age at enrollment',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (enrolled)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (grade)'],
#  ['Application mode',
#   'Course',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Age at enrollment',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)']]

# %%
# The element is in at least one list of optimal features
main_cols_max = features_best[0]
for i in range(len(features_best)-1):
    main_cols_max = list(set(main_cols_max) | set(features_best[i+1]))
main_cols_max
# Out:
# ['Tuition fees up to date',
#  'GDP',
#  "Father's qualification",
#  "Father's occupation",
#  'Daytime/evening attendance',
#  "Mother's qualification",
#  'Curricular units 2nd sem (approved)',
#  'Application order',
#  'Educational special needs',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 1st sem (without evaluations)',
#  'Unemployment rate',
#  'Displaced',
#  'Curricular units 1st sem (evaluations)',
#  'Gender',
#  'Course',
#  'Scholarship holder',
#  'Curricular units 1st sem (grade)',
#  'Application mode',
#  'Debtor',
#  'Curricular units 2nd sem (without evaluations)',
#  'Target',
#  'Curricular units 1st sem (credited)',
#  'International',
#  'Curricular units 2nd sem (enrolled)',
#  'Nacionality',
#  "Mother's occupation",
#  'Inflation rate',
#  'Age at enrollment',
#  'Marital status',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (enrolled)',
#  'Previous qualification']

# %%
len(main_cols_max)
# Out:
# 35

# %%
# The element is in all lists of optimal features
main_cols_min = features_best[0]
for i in range(len(features_best)-1):
    main_cols_min = list(set(main_cols_min).intersection(set(features_best[i+1])))
main_cols_min
# Out:
# ['Course',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (grade)',
#  "Father's occupation",
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (evaluations)',
#  'Age at enrollment']

# %%
# Most common items in all lists of optimal features
main_cols = []
main_cols_opt = {feature_name : 0 for feature_name in data.columns.tolist()}
for i in range(len(features_best)):
    for feature_name in features_best[i]:
        main_cols_opt[feature_name] += 1
df_main_cols_opt = pd.DataFrame.from_dict(main_cols_opt, orient='index', columns=['Target'])
df_main_cols_opt.sort_values(by=['Target'], ascending=False).head(num_features_opt)
# Out:
#                                                 Target
# Age at enrollment                                    4
# Curricular units 1st sem (evaluations)               4
# Curricular units 1st sem (grade)                     4
# Curricular units 2nd sem (evaluations)               4
# Curricular units 2nd sem (grade)                     4
# Father's occupation                                  4
# Course                                               4
# Curricular units 1st sem (approved)                  4
# Mother's qualification                               3
# Father's qualification                               3
# Mother's occupation                                  3
# Previous qualification                               3
# Tuition fees up to date                              3
# Application mode                                     3
# Curricular units 2nd sem (without evaluations)       2
# Unemployment rate                                    2
# Curricular units 2nd sem (approved)                  2
# Curricular units 2nd sem (enrolled)                  2
# Curricular units 1st sem (without evaluations)       2
# GDP                                                  2
# Marital status                                       2
# Curricular units 1st sem (enrolled)                  2
# Curricular units 1st sem (credited)                  2
# Scholarship holder                                   2
# Gender                                               2

# %%
main_cols = df_main_cols_opt.nlargest(num_features_opt, 'Target').index.tolist()
if not 'Target' in main_cols:
    main_cols.append('Target')
main_cols
# Out:
# ['Course',
#  "Father's occupation",
#  'Age at enrollment',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  'Application mode',
#  'Previous qualification',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  'Tuition fees up to date',
#  'Marital status',
#  'Application order',
#  'Daytime/evening attendance',
#  'Displaced',
#  'Debtor',
#  'Gender',
#  'Scholarship holder',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (enrolled)',
#  'Target']

# %% [markdown]
# Preparing the model

# %%
from sklearn.model_selection import train_test_split

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
# Target
target_name = 'Target'
target0 = data['Target']
train0 = data[main_cols].drop([target_name], axis=1)

# %% [markdown]
# Splitting the data

# %%
from sklearn.model_selection import train_test_split
train,test,target,target_test = train_test_split(train0, target0, test_size = 0.3,random_state=42)

# %%
metrics_all = {1 : 'r2_score', 2: 'acc', 3 : 're', 4 : 'precision', 5: 'f1_score', 6:'recall'}
metrics_now = [1, 2, 3, 4,5,6]

# %%
# list of accuracy of all model - amount of metrics_now * 2 (train & test datasets)
num_models = 6
acc_train = []
acc_test = []
acc_all = np.empty((len(metrics_now)*2, 0)).tolist()
acc_all
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], []]

# %%
acc_all_pred = np.empty((len(metrics_now), 0)).tolist()
acc_all_pred
# Out:
# [[], [], [], [], [], []]

# %%
# Splitting train data for model tuning with cross-validation
from sklearn.model_selection import ShuffleSplit
test_train_split_part = 0.2
cv_n_split = 3
random_state = 40

cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)

# %%
def acc_d(y_meas, y_pred):
    # Relative error between predicted y_pred and measured y_meas values
    return mean_absolute_error(y_meas, y_pred)*len(y_meas)/sum(abs(y_meas))

# %%
def plot_cm(target_test, test_pred):
    # Building the confusion matrices
    
    def cm_calc(y_true, y_pred):
        cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
        cm_sum = np.sum(cm, axis=1, keepdims=True)
        cm_perc = cm / cm_sum.astype(float) * 100
        annot = np.empty_like(cm).astype(str)
        nrows, ncols = cm.shape
        for i in range(nrows):
            for j in range(ncols):
                c = cm[i, j]
                p = cm_perc[i, j]
                if i == j:
                    s = cm_sum[i]
                    annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                elif c == 0:
                    annot[i, j] = ''
                else:
                    annot[i, j] = '%.1f%%\n%d' % (p, c)
        cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
        cm.index.name = 'Actual'
        cm.columns.name = 'Predicted'
        return cm, annot

    
    # Building the confusion matrices
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 6), sharex=True)
    
    # Test data
    ax.set_title("for test (validation) data")
    cm1, annot1 = cm_calc(target_test, test_pred)
    sns.heatmap(cm1, cmap= "YlGnBu", annot=annot1, fmt='', ax=ax)
    
    fig.suptitle('CONFUSION MATRICES')
    plt.show()

# %%
def acc_metrics_calc(num,model,train,test,target,target_test):
    # The models selection stage
    # Calculation of accuracy of model by different metrics
    global acc_all

    ytest = model.predict(test).astype(int)
    if num != 17:
        print('target_test =', target_test[:5].values)
        print('ytest =', ytest[:5])

    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_test = round(r2_score(target_test, ytest) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_test = round(metrics.accuracy_score(target_test, ytest) * 100, 2)
        elif x == 3:
            #rmse criterion
            acc_test = round(acc_rmse(target_test, ytest) * 100, 2)
        elif x == 4:
            #relative error criterion
            acc_test = round(acc_d(target_test, ytest) * 100, 2)
        elif x == 5:
            # precision score criterion
            precision_test = round(metrics.precision_score(target_test, ytest) * 100, 2)
        elif x == 6:
            # F1 score criterion
            f1_score_test = round(metrics.f1_score(target_test, ytest) * 100, 2)
        elif x == 7:
            # recall score criterion
            recall_test = round(metrics.recall_score(target_test, ytest) * 100, 2)
    
        
        print('acc of', metrics_all[x], 'for test =', acc_test)
        acc_all[num_acc+1].append(acc_test) #test
        num_acc += 2
    
    #  Building the confusion matrices
    plot_cm(target_test, ytest)

# %%
def acc_metrics_calc_pred(num,model,name_model,train,test,target):
    # The prediction stage
    # Calculation of accuracy of model for all different metrics and creates of the main submission file for the best model (num=0)
    global acc_all_pred

    ytrain = model.predict(train).astype(int)
    ytest = model.predict(test).astype(int)

    print('**********')
    print(name_model)
    if num != 17:
        print('target = ', target[:15].values)
        print('ytrain = ', ytrain[:15])
        print('ytest =', ytest[:15])
    
    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_train = round(r2_score(target, ytrain) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_train = round(metrics.accuracy_score(target, ytrain) * 100, 2)
        elif x == 3:
            #rmse criterion
            acc_train = round(acc_rmse(target, ytrain) * 100, 2)
        elif x == 4:
            #relative error criterion
            acc_train = round(acc_d(target, ytrain) * 100, 2)
        elif x == 5:
            #precision score criterion
            precision = round(metrics.precision_score(target, ytrain) * 100, 2)
        elif x == 6:
            #F1 score criterion
            f1_score = round(metrics.f1_score(target, ytrain) * 100, 2)
        elif x == 7:
            #recall score criterion
            recall = round(metrics.recall_score(target, ytrain) * 100, 2)     


        print('acc of', metrics_all[x], 'for train =', acc_train)
        acc_all_pred[num_acc].append(acc_train) #train
        num_acc += 1
    
    # Save the submission file
    submission[target_name] = ytest
    submission.to_csv('submission_' + name_model + '.csv', index=False)

# %% [markdown]
# Tuning and Testing features

# %%
# Thanks to https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html#sphx-glr-auto-examples-model-selection-plot-learning-curve-py
def plot_learning_curve(estimator, title, X, y, cv=None, axes=None, ylim=None, 
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5), random_state=0):
    fig, axes = plt.subplots(2, 1, figsize=(20, 10))
    
    if axes is None:
        _, axes = plt.subplots(1, 2, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    axes[0].set_xlabel("Training examples")
    axes[0].set_ylabel("Score")

    cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)
    
    train_sizes, train_scores, test_scores, fit_times, _ = \
        learning_curve(estimator=estimator, X=X, y=y, cv=cv,
                       train_sizes=train_sizes,
                       return_times=True)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # Plot learning curve
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    axes[0].legend(loc="best")

    # Plot n_samples vs fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, 'o-')
    axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                         fit_times_mean + fit_times_std, alpha=0.1)
    axes[1].set_xlabel("Training examples")
    axes[1].set_ylabel("fit_times")
    axes[1].set_title("Scalability of the model")

    plt.show()
    return

# %% [markdown]
# Support Vector Machines

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(train, target)
print(svr_CV.best_params_)
acc_metrics_calc(1,svr_CV,train,test,target,target_test)
# Out:
# {'kernel': 'linear', 'tol': 0.001}
# target_test = [1 0 0 1 0]
# ytest = [0 0 0 1 0]
# acc of r2_score for test = 60.25
# acc of acc for test = 90.63
# acc of re for test = 30.6
# acc of precision for test = 15.11
# acc of f1_score for test = 15.11
# acc of recall for test = 15.11

# %%
# Building learning curve of model
plot_learning_curve(svr, "Support Vector Machines", train, target, cv=cv_train)

# %% [markdown]
# MLP Classifier

# %%
# %%time
# MLPClassifier

mlp = MLPClassifier()
param_grid = {'hidden_layer_sizes': [i for i in range(2,5)],
              'solver': ['sgd'],
              'learning_rate': ['adaptive'],
              'max_iter': [1000]
              }
mlp_GS = GridSearchCV(mlp, param_grid=param_grid, cv=cv_train, verbose=False)
mlp_GS.fit(train, target)
print(mlp_GS.best_params_)
acc_metrics_calc(3,mlp_GS,train,test,target,target_test)
# Out:
# {'hidden_layer_sizes': 3, 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
# target =  [0 2 1 0 1]
# ytrain =  [2 2 2 2 2]
# target_test = [0 2 2 2 0]
# ytest = [2 2 2 2 2]
# acc of r2_score for train = -83.48
# acc of r2_score for test = -90.86
# acc of acc for train = 50.61
# acc of acc for test = 48.34
# acc of rmse for train = 120.14
# acc of rmse for test = 123.0
# acc of re for train = 68.12
# acc of re for test = 73.71
# CPU times: total: 12.5 s
# Wall time: 15.2 s

# %%
# Building learning curve of model
plot_learning_curve(mlp, "MLP Classifier", train, target, cv=cv_train)

# %% [markdown]
# Stochastic Gradient Descent

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier(early_stopping=True)
param_grid = {'alpha': [0.035, 0.04, 0.45]}
sgd_CV = GridSearchCV(sgd, param_grid=param_grid, cv=cv_train, verbose=False)
sgd_CV.fit(train, target)
print(sgd_CV.best_params_)
acc_metrics_calc(4,sgd_CV,train,test,target,target_test)
# Out:
# {'alpha': 0.45}
# target =  [0 2 1 0 1]
# ytrain =  [0 2 2 2 2]
# target_test = [0 2 2 2 0]
# ytest = [0 2 2 2 0]
# acc of r2_score for train = 33.65
# acc of r2_score for test = 28.37
# acc of acc for train = 74.06
# acc of acc for test = 71.91
# acc of rmse for train = 72.25
# acc of rmse for test = 75.35
# acc of re for train = 29.16
# acc of re for test = 32.7

# %%
# Building learning curve of model
plot_learning_curve(sgd, "Stochastic Gradient Descent", train, target, cv=cv_train)

# %% [markdown]
# Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
param_grid = {'min_samples_leaf': [i for i in range(2,10)]}
decision_tree_CV = GridSearchCV(decision_tree, param_grid=param_grid, cv=cv_train, verbose=False)
decision_tree_CV.fit(train, target)
print(decision_tree_CV.best_params_)
acc_metrics_calc(5,decision_tree_CV,train,test,target,target_test)
# Out:
# {'min_samples_leaf': 8}
# target =  [0 2 1 0 1]
# ytrain =  [0 2 2 0 1]
# target_test = [0 2 2 2 0]
# ytest = [0 2 2 2 0]
# acc of r2_score for train = 63.09
# acc of r2_score for test = 37.01
# acc of acc for train = 83.37
# acc of acc for test = 71.99
# acc of rmse for train = 53.89
# acc of rmse for test = 70.66
# acc of re for train = 17.46
# acc of re for test = 30.67

# %%
# Building learning curve of model
plot_learning_curve(decision_tree_CV, "Decision Tree", train, target, cv=cv_train)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (2.0.0)
# Requirement already satisfied: numpy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.11.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost as xgb

# %%
# %%time
# XGBoost Classifier
xgb_clf = xgb.XGBClassifier(objective='reg:squarederror') 
parameters = {'n_estimators': [50, 60, 70, 80, 90], 
              'learning_rate': [0.09, 0.1, 0.15, 0.2],
              'max_depth': [3, 4, 5]}
xgb_reg = GridSearchCV(estimator=xgb_clf, param_grid=parameters, cv=cv_train).fit(train, target)
print("Best score: %0.3f" % xgb_reg.best_score_)
print("Best parameters set:", xgb_reg.best_params_)
acc_metrics_calc(7,xgb_reg,train,test,target,target_test)
# Out:
# Best score: 0.780
# Best parameters set: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 90}
# target =  [0 2 1 0 1]
# ytrain =  [0 2 2 0 2]
# target_test = [0 2 2 2 0]
# ytest = [0 2 2 2 0]
# acc of r2_score for train = 63.95
# acc of r2_score for test = 47.75
# acc of acc for train = 84.63
# acc of acc for test = 76.88
# acc of rmse for train = 53.25
# acc of rmse for test = 64.36
# acc of re for train = 16.56
# acc of re for test = 25.38
# CPU times: total: 3min 45s
# Wall time: 35.5 s

# %%
# Building learning curve of model
plot_learning_curve(xgb_clf, "XGBoost Classifier", train, target, cv=cv_train)

# %% [markdown]
# Neural Network with Keras

# %%
def build_nn(optimizer='adam'):

    # Initializing the NN
    nn = Sequential()

    # Adding the input layer and the first hidden layer of the NN
    nn.add(Dense(units=32, kernel_initializer='he_normal', activation='relu', input_shape=(len(train0.columns),)))
    # Adding the output layer
    nn.add(Dense(units=1, kernel_initializer='he_normal', activation='sigmoid'))

    # Compiling the NN
    nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return nn

Xtrain, Xval, Ztrain, Zval = train_test_split(train, target, test_size=test_train_split_part, random_state=random_state)
nn_model = build_nn(optimizers.Adam(lr=0.0001))
nn_model.fit(Xtrain, Ztrain, batch_size=16, epochs=100, validation_data=(Xval, Zval))
acc_metrics_calc(17,nn_model,train,test,target,target_test)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 155/155 [==============================] - 1s 3ms/step - loss: -4.3119 - accuracy: 0.1846 - val_loss: -15.8607 - val_accuracy: 0.1758
# Epoch 2/100
# 155/155 [==============================] - 0s 2ms/step - loss: -33.9847 - accuracy: 0.1777 - val_loss: -62.5257 - val_accuracy: 0.1758
# Epoch 3/100
# 155/155 [==============================] - 0s 2ms/step - loss: -97.4964 - accuracy: 0.1777 - val_loss: -150.1393 - val_accuracy: 0.1758
# Epoch 4/100
# 155/155 [==============================] - 0s 3ms/step - loss: -201.7130 - accuracy: 0.1777 - val_loss: -277.9354 - val_accuracy: 0.1758
# Epoch 5/100
# 155/155 [==============================] - 0s 2ms/step - loss: -342.3886 - accuracy: 0.1777 - val_loss: -437.0837 - val_accuracy: 0.1758
# Epoch 6/100
# 155/155 [==============================] - 0s 2ms/step - loss: -514.5991 - accuracy: 0.1777 - val_loss: -629.8911 - val_accuracy: 0.1758
# Epoch 7/100
# 155/155 [==============================] - 0s 2ms/step - loss: -716.3765 - accuracy: 0.1777 - val_loss: -853.8736 - val_accuracy: 0.1758
# Epoch 8/100
# 155/155 [==============================] - 0s 2ms/step - loss: -949.5643 - accuracy: 0.1777 - val_loss: -1110.8038 - val_accuracy: 0.1758
# Epoch 9/100
# 155/155 [==============================] - 0s 2ms/step - loss: -1213.5697 - accuracy: 0.1777 - val_loss: -1397.1899 - val_accuracy: 0.1758
# Epoch 10/100
# 155/155 [==============================] - 0s 2ms/step - loss: -1505.4751 - accuracy: 0.1777 - val_loss: -1713.0623 - val_accuracy: 0.1758
# Epoch 11/100
# 155/155 [==============================] - 0s 3ms/step - loss: -1825.2203 - accuracy: 0.1777 - val_loss: -2049.7852 - val_accuracy: 0.1758
# Epoch 12/100
# 155/155 [==============================] - 0s 2ms/step - loss: -2172.0149 - accuracy: 0.1777 - val_loss: -2427.7869 - val_accuracy: 0.1758
# Epoch 13/100
# 155/155 [==============================] - 0s 3ms/step - loss: -2545.9363 - accuracy: 0.1777 - val_loss: -2819.2815 - val_accuracy: 0.1758
# Epoch 14/100
# 155/155 [==============================] - 0s 2ms/step - loss: -2941.2451 - accuracy: 0.1777 - val_loss: -3241.3064 - val_accuracy: 0.1758
# Epoch 15/100
# 155/155 [==============================] - 0s 2ms/step - loss: -3359.5227 - accuracy: 0.1777 - val_loss: -3689.6670 - val_accuracy: 0.1758
# Epoch 16/100
# 155/155 [==============================] - 0s 2ms/step - loss: -3798.4866 - accuracy: 0.1777 - val_loss: -4151.6533 - val_accuracy: 0.1758
# Epoch 17/100
# 155/155 [==============================] - 0s 3ms/step - loss: -4260.6143 - accuracy: 0.1777 - val_loss: -4638.0410 - val_accuracy: 0.1758
# Epoch 18/100
# 155/155 [==============================] - 0s 3ms/step - loss: -4744.0513 - accuracy: 0.1777 - val_loss: -5151.3716 - val_accuracy: 0.1758
# Epoch 19/100
# 155/155 [==============================] - 1s 4ms/step - loss: -5251.6631 - accuracy: 0.1777 - val_loss: -5670.5430 - val_accuracy: 0.1758
# Epoch 20/100
# 155/155 [==============================] - 1s 3ms/step - loss: -5777.7607 - accuracy: 0.1777 - val_loss: -6226.6050 - val_accuracy: 0.1758
# Epoch 21/100
# 155/155 [==============================] - 0s 3ms/step - loss: -6322.9751 - accuracy: 0.1777 - val_loss: -6800.4541 - val_accuracy: 0.1758
# Epoch 22/100
# 155/155 [==============================] - 0s 2ms/step - loss: -6888.4951 - accuracy: 0.1777 - val_loss: -7380.4111 - val_accuracy: 0.1758
# Epoch 23/100
# 155/155 [==============================] - 0s 3ms/step - loss: -7472.5718 - accuracy: 0.1777 - val_loss: -8000.8799 - val_accuracy: 0.1758
# Epoch 24/100
# 155/155 [==============================] - 1s 4ms/step - loss: -8072.0737 - accuracy: 0.1777 - val_loss: -8628.1729 - val_accuracy: 0.1758
# Epoch 25/100
# 155/155 [==============================] - 1s 4ms/step - loss: -8692.1553 - accuracy: 0.1777 - val_loss: -9281.3672 - val_accuracy: 0.1758
# Epoch 26/100
# 155/155 [==============================] - 1s 4ms/step - loss: -9332.8770 - accuracy: 0.1777 - val_loss: -9931.5225 - val_accuracy: 0.1758
# Epoch 27/100
# 155/155 [==============================] - 0s 3ms/step - loss: -9991.2686 - accuracy: 0.1777 - val_loss: -10620.1592 - val_accuracy: 0.1758
# Epoch 28/100
# 155/155 [==============================] - 0s 3ms/step - loss: -10668.4307 - accuracy: 0.1777 - val_loss: -11340.0205 - val_accuracy: 0.1758
# Epoch 29/100
# 155/155 [==============================] - 0s 3ms/step - loss: -11365.0469 - accuracy: 0.1777 - val_loss: -12045.1982 - val_accuracy: 0.1758
# Epoch 30/100
# 155/155 [==============================] - 0s 3ms/step - loss: -12076.7549 - accuracy: 0.1777 - val_loss: -12799.0117 - val_accuracy: 0.1758
# Epoch 31/100
# 155/155 [==============================] - 0s 3ms/step - loss: -12806.7246 - accuracy: 0.1777 - val_loss: -13558.0000 - val_accuracy: 0.1758
# Epoch 32/100
# 155/155 [==============================] - 0s 3ms/step - loss: -13551.5156 - accuracy: 0.1777 - val_loss: -14327.3223 - val_accuracy: 0.1758
# Epoch 33/100
# 155/155 [==============================] - 0s 3ms/step - loss: -14312.3008 - accuracy: 0.1777 - val_loss: -15126.6309 - val_accuracy: 0.1758
# Epoch 34/100
# 155/155 [==============================] - 1s 3ms/step - loss: -15094.1699 - accuracy: 0.1777 - val_loss: -15918.6982 - val_accuracy: 0.1758
# Epoch 35/100
# 155/155 [==============================] - 0s 3ms/step - loss: -15889.8623 - accuracy: 0.1777 - val_loss: -16759.9766 - val_accuracy: 0.1758
# Epoch 36/100
# 155/155 [==============================] - 1s 4ms/step - loss: -16706.6465 - accuracy: 0.1777 - val_loss: -17591.7832 - val_accuracy: 0.1758
# Epoch 37/100
# 155/155 [==============================] - 0s 3ms/step - loss: -17538.9961 - accuracy: 0.1777 - val_loss: -18472.4590 - val_accuracy: 0.1758
# Epoch 38/100
# 155/155 [==============================] - 0s 3ms/step - loss: -18392.7285 - accuracy: 0.1777 - val_loss: -19351.5938 - val_accuracy: 0.1758
# Epoch 39/100
# 155/155 [==============================] - 0s 3ms/step - loss: -19262.1250 - accuracy: 0.1777 - val_loss: -20276.2266 - val_accuracy: 0.1758
# Epoch 40/100
# 155/155 [==============================] - 0s 3ms/step - loss: -20154.1367 - accuracy: 0.1777 - val_loss: -21185.4941 - val_accuracy: 0.1758
# Epoch 41/100
# 155/155 [==============================] - 0s 3ms/step - loss: -21063.7363 - accuracy: 0.1777 - val_loss: -22127.7305 - val_accuracy: 0.1758
# Epoch 42/100
# 155/155 [==============================] - 0s 3ms/step - loss: -21989.7598 - accuracy: 0.1777 - val_loss: -23088.5098 - val_accuracy: 0.1758
# Epoch 43/100
# 155/155 [==============================] - 0s 3ms/step - loss: -22928.2441 - accuracy: 0.1777 - val_loss: -24055.8203 - val_accuracy: 0.1758
# Epoch 44/100
# 155/155 [==============================] - 0s 3ms/step - loss: -23880.9219 - accuracy: 0.1777 - val_loss: -25055.4668 - val_accuracy: 0.1758
# Epoch 45/100
# 155/155 [==============================] - 0s 3ms/step - loss: -24858.9492 - accuracy: 0.1777 - val_loss: -26063.4004 - val_accuracy: 0.1758
# Epoch 46/100
# 155/155 [==============================] - 0s 3ms/step - loss: -25857.3086 - accuracy: 0.1777 - val_loss: -27097.2617 - val_accuracy: 0.1758
# Epoch 47/100
# 155/155 [==============================] - 0s 2ms/step - loss: -26874.1562 - accuracy: 0.1777 - val_loss: -28148.8418 - val_accuracy: 0.1758
# Epoch 48/100
# 155/155 [==============================] - 0s 3ms/step - loss: -27899.8613 - accuracy: 0.1777 - val_loss: -29233.2969 - val_accuracy: 0.1758
# Epoch 49/100
# 155/155 [==============================] - 0s 2ms/step - loss: -28944.9082 - accuracy: 0.1777 - val_loss: -30282.5781 - val_accuracy: 0.1758
# Epoch 50/100
# 155/155 [==============================] - 0s 2ms/step - loss: -29994.3691 - accuracy: 0.1777 - val_loss: -31393.9648 - val_accuracy: 0.1758
# Epoch 51/100
# 155/155 [==============================] - 0s 2ms/step - loss: -31066.8984 - accuracy: 0.1777 - val_loss: -32482.6738 - val_accuracy: 0.1758
# Epoch 52/100
# 155/155 [==============================] - 0s 2ms/step - loss: -32151.6875 - accuracy: 0.1777 - val_loss: -33639.4414 - val_accuracy: 0.1758
# Epoch 53/100
# 155/155 [==============================] - 0s 2ms/step - loss: -33260.5703 - accuracy: 0.1777 - val_loss: -34747.1250 - val_accuracy: 0.1758
# Epoch 54/100
# 155/155 [==============================] - 0s 2ms/step - loss: -34382.0859 - accuracy: 0.1777 - val_loss: -35920.1250 - val_accuracy: 0.1758
# Epoch 55/100
# 155/155 [==============================] - 0s 2ms/step - loss: -35519.6484 - accuracy: 0.1777 - val_loss: -37092.8594 - val_accuracy: 0.1758
# Epoch 56/100
# 155/155 [==============================] - 0s 2ms/step - loss: -36675.4180 - accuracy: 0.1777 - val_loss: -38262.6914 - val_accuracy: 0.1758
# Epoch 57/100
# 155/155 [==============================] - 0s 3ms/step - loss: -37842.5312 - accuracy: 0.1777 - val_loss: -39499.4531 - val_accuracy: 0.1758
# Epoch 58/100
# 155/155 [==============================] - 1s 3ms/step - loss: -39028.4844 - accuracy: 0.1777 - val_loss: -40700.1289 - val_accuracy: 0.1758
# Epoch 59/100
# 155/155 [==============================] - 0s 3ms/step - loss: -40230.2344 - accuracy: 0.1777 - val_loss: -41959.6406 - val_accuracy: 0.1758
# Epoch 60/100
# 155/155 [==============================] - 0s 3ms/step - loss: -41449.4961 - accuracy: 0.1777 - val_loss: -43226.5039 - val_accuracy: 0.1758
# Epoch 61/100
# 155/155 [==============================] - 0s 2ms/step - loss: -42688.1875 - accuracy: 0.1777 - val_loss: -44488.2852 - val_accuracy: 0.1758
# Epoch 62/100
# 155/155 [==============================] - 0s 3ms/step - loss: -43943.1094 - accuracy: 0.1777 - val_loss: -45804.3086 - val_accuracy: 0.1758
# Epoch 63/100
# 155/155 [==============================] - 0s 3ms/step - loss: -45211.4414 - accuracy: 0.1777 - val_loss: -47098.0430 - val_accuracy: 0.1758
# Epoch 64/100
# 155/155 [==============================] - 0s 2ms/step - loss: -46488.5156 - accuracy: 0.1777 - val_loss: -48414.5977 - val_accuracy: 0.1758
# Epoch 65/100
# 155/155 [==============================] - 0s 2ms/step - loss: -47775.1406 - accuracy: 0.1777 - val_loss: -49768.4297 - val_accuracy: 0.1758
# Epoch 66/100
# 155/155 [==============================] - 0s 2ms/step - loss: -49079.8242 - accuracy: 0.1777 - val_loss: -51097.6250 - val_accuracy: 0.1758
# Epoch 67/100
# 155/155 [==============================] - 1s 3ms/step - loss: -50404.4531 - accuracy: 0.1777 - val_loss: -52441.5078 - val_accuracy: 0.1758
# Epoch 68/100
# 155/155 [==============================] - 1s 4ms/step - loss: -51744.9062 - accuracy: 0.1777 - val_loss: -53846.4883 - val_accuracy: 0.1758
# Epoch 69/100
# 155/155 [==============================] - 0s 3ms/step - loss: -53097.4570 - accuracy: 0.1777 - val_loss: -55237.4570 - val_accuracy: 0.1758
# Epoch 70/100
# 155/155 [==============================] - 0s 3ms/step - loss: -54469.5117 - accuracy: 0.1777 - val_loss: -56662.6523 - val_accuracy: 0.1758
# Epoch 71/100
# 155/155 [==============================] - 0s 2ms/step - loss: -55861.3438 - accuracy: 0.1777 - val_loss: -58096.0898 - val_accuracy: 0.1758
# Epoch 72/100
# 155/155 [==============================] - 0s 2ms/step - loss: -57268.3047 - accuracy: 0.1777 - val_loss: -59545.9922 - val_accuracy: 0.1758
# Epoch 73/100
# 155/155 [==============================] - 0s 2ms/step - loss: -58692.1875 - accuracy: 0.1777 - val_loss: -61010.7734 - val_accuracy: 0.1758
# Epoch 74/100
# 155/155 [==============================] - 0s 2ms/step - loss: -60136.3281 - accuracy: 0.1777 - val_loss: -62508.6836 - val_accuracy: 0.1758
# Epoch 75/100
# 155/155 [==============================] - 0s 2ms/step - loss: -61595.9023 - accuracy: 0.1777 - val_loss: -64012.5273 - val_accuracy: 0.1758
# Epoch 76/100
# 155/155 [==============================] - 0s 3ms/step - loss: -63072.5508 - accuracy: 0.1777 - val_loss: -65530.7031 - val_accuracy: 0.1758
# Epoch 77/100
# 155/155 [==============================] - 0s 2ms/step - loss: -64565.5391 - accuracy: 0.1777 - val_loss: -67077.8672 - val_accuracy: 0.1758
# Epoch 78/100
# 155/155 [==============================] - 0s 2ms/step - loss: -66080.3516 - accuracy: 0.1777 - val_loss: -68654.4297 - val_accuracy: 0.1758
# Epoch 79/100
# 155/155 [==============================] - 0s 2ms/step - loss: -67607.6250 - accuracy: 0.1777 - val_loss: -70241.5312 - val_accuracy: 0.1758
# Epoch 80/100
# 155/155 [==============================] - 0s 3ms/step - loss: -69156.0625 - accuracy: 0.1777 - val_loss: -71846.6719 - val_accuracy: 0.1758
# Epoch 81/100
# 155/155 [==============================] - 0s 2ms/step - loss: -70729.7891 - accuracy: 0.1777 - val_loss: -73411.3516 - val_accuracy: 0.1758
# Epoch 82/100
# 155/155 [==============================] - 0s 2ms/step - loss: -72316.0625 - accuracy: 0.1777 - val_loss: -75080.8359 - val_accuracy: 0.1758
# Epoch 83/100
# 155/155 [==============================] - 0s 3ms/step - loss: -73920.8594 - accuracy: 0.1777 - val_loss: -76713.9766 - val_accuracy: 0.1758
# Epoch 84/100
# 155/155 [==============================] - 0s 3ms/step - loss: -75541.4219 - accuracy: 0.1777 - val_loss: -78403.7812 - val_accuracy: 0.1758
# Epoch 85/100
# 155/155 [==============================] - 0s 3ms/step - loss: -77174.5625 - accuracy: 0.1777 - val_loss: -80076.2422 - val_accuracy: 0.1758
# Epoch 86/100
# 155/155 [==============================] - 0s 2ms/step - loss: -78823.8359 - accuracy: 0.1777 - val_loss: -81804.6719 - val_accuracy: 0.1758
# Epoch 87/100
# 155/155 [==============================] - 0s 2ms/step - loss: -80492.3984 - accuracy: 0.1777 - val_loss: -83514.3594 - val_accuracy: 0.1758
# Epoch 88/100
# 155/155 [==============================] - 0s 2ms/step - loss: -82179.7188 - accuracy: 0.1777 - val_loss: -85240.2734 - val_accuracy: 0.1758
# Epoch 89/100
# 155/155 [==============================] - 0s 3ms/step - loss: -83881.7109 - accuracy: 0.1777 - val_loss: -86973.3516 - val_accuracy: 0.1758
# Epoch 90/100
# 155/155 [==============================] - 0s 2ms/step - loss: -85591.3672 - accuracy: 0.1777 - val_loss: -88768.6797 - val_accuracy: 0.1758
# Epoch 91/100
# 155/155 [==============================] - 0s 3ms/step - loss: -87314.4453 - accuracy: 0.1777 - val_loss: -90517.8906 - val_accuracy: 0.1758
# Epoch 92/100
# 155/155 [==============================] - 0s 2ms/step - loss: -89034.0078 - accuracy: 0.1777 - val_loss: -92339.2891 - val_accuracy: 0.1758
# Epoch 93/100
# 155/155 [==============================] - 0s 2ms/step - loss: -90787.8984 - accuracy: 0.1777 - val_loss: -94123.4297 - val_accuracy: 0.1758
# Epoch 94/100
# 155/155 [==============================] - 0s 2ms/step - loss: -92547.3203 - accuracy: 0.1777 - val_loss: -95891.1641 - val_accuracy: 0.1758
# Epoch 95/100
# 155/155 [==============================] - 0s 2ms/step - loss: -94323.8828 - accuracy: 0.1777 - val_loss: -97751.8438 - val_accuracy: 0.1758
# Epoch 96/100
# 155/155 [==============================] - 0s 2ms/step - loss: -96126.4297 - accuracy: 0.1777 - val_loss: -99646.7109 - val_accuracy: 0.1758
# Epoch 97/100
# 155/155 [==============================] - 0s 2ms/step - loss: -97951.8125 - accuracy: 0.1777 - val_loss: -101480.9609 - val_accuracy: 0.1758
# Epoch 98/100
# 155/155 [==============================] - 0s 2ms/step - loss: -99786.4766 - accuracy: 0.1777 - val_loss: -103437.7500 - val_accuracy: 0.1758
# Epoch 99/100
# 155/155 [==============================] - 0s 2ms/step - loss: -101650.2734 - accuracy: 0.1777 - val_loss: -105330.4609 - val_accuracy: 0.1758
# Epoch 100/100
# 155/155 [==============================] - 0s 2ms/step - loss: -103512.7422 - accuracy: 0.1777 - val_loss: -107253.1875 - val_accuracy: 0.1758
# 97/97 [==============================] - 0s 1ms/step
# 42/42 [==============================] - 0s 1ms/step
# acc of r2_score for train = -4.57
# acc of r2_score for test = -2.89
# acc of acc for train = 17.73
# acc of acc for test = 18.45
# acc of rmse for train = 90.7
# acc of rmse for test = 90.31
# acc of re for train = 69.16
# acc of re for test = 70.83

# %% [markdown]
# Gaussian Process

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
print(gpc_CV.best_params_)
acc_metrics_calc(18,gpc_CV,train,test,target,target_test)
# Out:
# {'max_iter_predict': 70, 'n_restarts_optimizer': 2, 'warm_start': False}
# target =  [0 2 1 0 1]
# ytrain =  [0 2 1 0 1]
# target_test = [0 2 2 2 0]
# ytest = [2 1 2 1 2]
# acc of r2_score for train = 100.0
# acc of r2_score for test = -27.4
# acc of acc for train = 100.0
# acc of acc for test = 57.53
# acc of rmse for train = 0.0
# acc of rmse for test = 100.49
# acc of re for train = 0.0
# acc of re for test = 53.83

# %%
# Building learning curve of model
plot_learning_curve(gpc, "Gaussian Process Classification", train, target, cv=cv_train)

# %% [markdown]
# Model Evaluation

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines','MLP Classifier', 'Stochastic Gradient Decent', 'Decision Tree Classifier','XGB Classifier',
              'NN model', 'Gaussian Process Classification'  ]})

# %%
for x in metrics_now:
    xs = metrics_all[x]
    models[xs + '_train'] = acc_all[(x-1)*2]
    models[xs + '_test'] = acc_all[(x-1)*2+1]
    if xs == "acc":
        models[xs + '_diff'] = models[xs + '_train'] - models[xs + '_test']

# %%
print('Prediction accuracy for models')
ms = metrics_all[metrics_now[1]] # the first from metrics
models[['Model', ms + '_train', ms + '_test', 'acc_diff']].sort_values(by=[(ms + '_test'), (ms + '_train')], ascending=False)
# Out:
# Prediction accuracy for models
#                              Model  acc_train  acc_test  acc_diff
# 6  Gaussian Process Classification      84.63     76.88      7.75
# 0          Support Vector Machines      78.00     75.75      2.25
# 3         Decision Tree Classifier      83.37     71.99     11.38
# 2       Stochastic Gradient Decent      74.06     71.91      2.15
# 5                         NN model     100.00     57.53     42.47
# 1                   MLP Classifier      50.61     48.34      2.27
# 4                   XGB Classifier      17.73     18.45     -0.72

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
for x in metrics_now:   
    # Plot
    xs = metrics_all[x]
    xs_train = metrics_all[x] + '_train'
    xs_test = metrics_all[x] + '_test'
    plt.figure(figsize=[15,6])
    xx = models['Model']
    plt.tick_params(labelsize=14)
    plt.plot(xx, models[xs_train], label = xs_train)
    plt.plot(xx, models[xs_test], label = xs_test)
    plt.legend()
    plt.title(str(xs) + ' criterion for ' + str(num_models) + ' models for train and test datasets')
    plt.xlabel('Models')
    plt.ylabel(xs + ', %')
    plt.xticks(xx, rotation='vertical')
    plt.show()

# %% [markdown]
# Extension

# %%
# Split the data and targets into training/testing sets
X_train, X_test, y_train, y_test = train_test_split(
        train, target, test_size=0.2, random_state=3)

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=40, test_size=0.2, train_size=None),
#              estimator=SVC(),
#              param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                          'tol': [0.001]},
#              verbose=False)

# %%
print(svr_CV.best_params_)
acc_metrics_calc(1,svr_CV,train,test,target,target_test)
# Out:
# {'kernel': 'linear', 'tol': 0.001}
# target =  [0 2 1 0 1]
# ytrain =  [0 2 2 2 2]
# target_test = [0 2 2 2 0]
# ytest = [0 2 2 2 0]
# acc of r2_score for train = 49.46
# acc of r2_score for test = 46.89
# acc of acc for train = 77.58
# acc of acc for test = 75.75
# acc of rmse for train = 63.06
# acc of rmse for test = 64.88
# acc of re for train = 23.7
# acc of re for test = 26.23

# %%
# Make predictions using the testing set
svr_pred = svr_CV.predict(X_test)

# %%
#Using two features in the data set for plotting possibility. We can take any 2
svr_X_train = X_train.iloc[:, [2, 10]]
svr_y_train= y_train

# %%
svr_X_train.head()
# Out:
#       Father's occupation  Mother's qualification
# 53                     12                      22
# 2959                    3                       2
# 1701                    6                       1
# 826                     8                       1
# 3557                    5                       1

# %%
h = .02  # step size in the mesh

svr_CV.fit(svr_X_train, svr_y_train)

svr_X = X_test.iloc[:, [2,3]]
svr_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
sp = time.time()
time_taken = sp-st
print('This project took', time_taken, 'seconds to execute')
# Out:
# This project took 4407.5593276023865 seconds to execute

# %% [markdown]
# Cross Validation

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
print(gpc_CV.best_params_)
acc_metrics_calc(18,gpc_CV,X_train,X_test, y_train, y_test)
# Out:
# {'max_iter_predict': 70, 'n_restarts_optimizer': 2, 'warm_start': False}
# target =  [2 2 2 0 0]
# ytrain =  [2 2 2 0 0]
# target_test = [2 2 0 0 0]
# ytest = [2 2 0 0 0]
# acc of r2_score for train = 100.0
# acc of r2_score for test = 100.0
# acc of acc for train = 100.0
# acc of acc for test = 100.0
# acc of rmse for train = 0.0
# acc of rmse for test = 0.0
# acc of re for train = 0.0
# acc of re for test = 0.0

# %%
# Make predictions using the testing set
gaus_pred = gpc_CV.predict(X_test)

# %%
X_train
# Out:
#       Course  Mother's occupation  Father's occupation  Age at enrollment  \
# 53         8                   12                   12                 19
# 2959      11                    3                    3                 62
# 1701      15                    6                    6                 18
# 826       16                    6                    8                 18
# 3557       4                   10                    5                 25
# ...      ...                  ...                  ...                ...
# 2367       8                    3                    9                 18
# 870       11                   29                   44                 20
# 3138      15                    5                    4                 19
# 2040      16                   10                   10                 20
# 1792      17                    3                    3                 29
#
#       Curricular units 1st sem (evaluations)  \
# 53                                         7
# 2959                                       7
# 1701                                       6
# 826                                        8
# 3557                                       0
# ...                                      ...
# 2367                                       7
# 870                                        8
# 3138                                       6
# 2040                                       9
# 1792                                       9
#
#       Curricular units 1st sem (grade)  \
# 53                               14.71
# 2959                             15.00
# 1701                             13.67
# 826                              11.57
# 3557                              0.00
# ...                                ...
# 2367                             14.00
# 870                              13.14
# 3138                             13.17
# 2040                             11.67
# 1792                             11.00
#
#       Curricular units 2nd sem (evaluations)  \
# 53                                         5
# 2959                                      10
# 1701                                       6
# 826                                        9
# 3557                                       0
# ...                                      ...
# 2367                                       8
# 870                                        7
# 3138                                       6
# 2040                                      10
# 1792                                      11
#
#       Curricular units 2nd sem (grade)  Application mode  \
# 53                               15.80                 1
# 2959                             12.83                12
# 1701                             14.50                 1
# 826                              13.17                 8
# 3557                              0.00                12
# ...                                ...               ...
# 2367                             13.67                 8
# 870                              12.50                 1
# 3138                             15.00                 1
# 2040                             11.00                 1
# 1792                             13.50                12
#
#       Previous qualification  ...  Marital status  Application order  \
# 53                         1  ...               1                  3
# 2959                       1  ...               5                  1
# 1701                       1  ...               1                  1
# 826                        1  ...               1                  1
# 3557                       1  ...               1                  1
# ...                      ...  ...             ...                ...
# 2367                       1  ...               1                  1
# 870                        1  ...               1                  1
# 3138                       1  ...               1                  1
# 2040                       1  ...               1                  5
# 1792                       1  ...               1                  1
#
#       Daytime/evening attendance  Nacionality  Displaced  Debtor  Gender  \
# 53                             1            1          0       0       0
# 2959                           1            1          0       0       0
# 1701                           1            1          1       0       1
# 826                            1            1          1       0       0
# 3557                           1            1          0       0       1
# ...                          ...          ...        ...     ...     ...
# 2367                           1            1          1       0       1
# 870                            1            1          0       0       1
# 3138                           1            1          0       0       0
# 2040                           1            1          1       1       0
# 1792                           0            1          0       1       1
#
#       Scholarship holder  Curricular units 1st sem (credited)  \
# 53                     0                                    0
# 2959                   0                                    0
# 1701                   0                                    0
# 826                    0                                    0
# 3557                   0                                    0
# ...                  ...                                  ...
# 2367                   0                                    0
# 870                    0                                    0
# 3138                   0                                    0
# 2040                   0                                    0
# 1792                   0                                    1
#
#       Curricular units 1st sem (enrolled)
# 53                                      5
# 2959                                    6
# 1701                                    6
# 826                                     7
# 3557                                    6
# ...                                   ...
# 2367                                    6
# 870                                     6
# 3138                                    6
# 2040                                    6
# 1792                                    5
#
# [2476 rows x 25 columns]

# %%
#Using two features in the data set for plotting possibility. We can take any 2
gaus_X_train = X_train.iloc[:, [2, 10]]
gaus_y_train= y_train

# %%
h = .02  # step size in the mesh

gpc_CV.fit(gaus_X_train, gaus_y_train)

gaus_X = X_test.iloc[:, [2,3]]
gaus_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\multiclass.py:105, in _predict_binary(estimator, X)
#     104 try:
# --> 105     score = np.ravel(estimator.decision_function(X))
#     106 except (AttributeError, NotImplementedError):
#     107     # probabilities of the positive class
#
# AttributeError: '_BinaryGaussianProcessClassifierLaplace' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# Cell In[105], line 7
#       4 y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
#       5 xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
#       6                      np.arange(y_min, y_max,h))
# ----> 7 Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:519, in BaseSearchCV.predict(self, X)
#     501 """Call predict on the estimator with the best found parameters.
#     502
#     503 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     516     the best found parameters.
#     517 """
#     518 check_is_fitted(self)
# --> 519 return self.best_estimator_.predict(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\_gpc.py:777, in GaussianProcessClassifier.predict(self, X)
#     774 else:
#     775     X = self._validate_data(X, ensure_2d=False, dtype=None, reset=False)
# --> 777 return self.base_estimator_.predict(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\multiclass.py:449, in OneVsRestClassifier.predict(self, X)
#     447 argmaxima = np.zeros(n_samples, dtype=int)
#     448 for i, e in enumerate(self.estimators_):
# --> 449     pred = _predict_binary(e, X)
#     450     np.maximum(maxima, pred, out=maxima)
#     451     argmaxima[maxima == pred] = i
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\multiclass.py:108, in _predict_binary(estimator, X)
#     105     score = np.ravel(estimator.decision_function(X))
#     106 except (AttributeError, NotImplementedError):
#     107     # probabilities of the positive class
# --> 108     score = estimator.predict_proba(X)[:, 1]
#     109 return score
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\_gpc.py:311, in _BinaryGaussianProcessClassifierLaplace.predict_proba(self, X)
#     308 check_is_fitted(self)
#     310 # Based on Algorithm 3.2 of GPML
# --> 311 K_star = self.kernel_(self.X_train_, X)  # K_star =k(x_star)
#     312 f_star = K_star.T.dot(self.y_train_ - self.pi_)  # Line 4
#     313 v = solve(self.L_, self.W_sr_[:, np.newaxis] * K_star)  # Line 5
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\kernels.py:945, in Product.__call__(self, X, Y, eval_gradient)
#     941     return K1 * K2, np.dstack(
#     942         (K1_gradient * K2[:, :, np.newaxis], K2_gradient * K1[:, :, np.newaxis])
#     943     )
#     944 else:
# --> 945     return self.k1(X, Y) * self.k2(X, Y)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\kernels.py:1252, in ConstantKernel.__call__(self, X, Y, eval_gradient)
#    1249 elif eval_gradient:
#    1250     raise ValueError("Gradient can only be evaluated when Y is None.")
# -> 1252 K = np.full(
#    1253     (_num_samples(X), _num_samples(Y)),
#    1254     self.constant_value,
#    1255     dtype=np.array(self.constant_value).dtype,
#    1256 )
#    1257 if eval_gradient:
#    1258     if not self.hyperparameter_constant_value.fixed:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\numeric.py:344, in full(shape, fill_value, dtype, order, like)
#     342     fill_value = asarray(fill_value)
#     343     dtype = fill_value.dtype
# --> 344 a = empty(shape, dtype, order)
#     345 multiarray.copyto(a, fill_value, casting='unsafe')
#     346 return a
#
# MemoryError: Unable to allocate 80.9 GiB for an array with shape (2476, 4387500) and data type float64

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
import numpy as np
import pandas as pd
import ydata_profiling as pp
import math
import random
import seaborn as sns
import matplotlib.pyplot as plt
import time 

st = time.time()

# %matplotlib inline

# %%
# preprocessing
import sklearn
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score, confusion_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel, SelectKBest, RFE, chi2
from sklearn.model_selection import learning_curve

# models
from sklearn.linear_model import LogisticRegression, Perceptron, RidgeClassifier, SGDClassifier, LassoCV
from sklearn.svm import SVC, LinearSVC, SVR
from sklearn.ensemble import RandomForestClassifier 
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# NN models
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
#from keras.wrappers.scikit_learn import KerasClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\okechukwu chude\Documents\MOdeling and optimisation\Predict students' dropout and success\Predict-students--dropout-and-academic-success\dataset.csv")

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
#
# [3 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
#  9   Mother's occupation                             4424 non-null   int64
#  10  Father's occupation                             4424 non-null   int64
#  11  Displaced                                       4424 non-null   int64
#  12  Educational special needs                       4424 non-null   int64
#  13  Debtor                                          4424 non-null   int64
#  14  Tuition fees up to date                         4424 non-null   int64
#  15  Gender                                          4424 non-null   int64
#  16  Scholarship holder                              4424 non-null   int64
#  17  Age at enrollment                               4424 non-null   int64
#  18  International                                   4424 non-null   int64
#  19  Curricular units 1st sem (credited)             4424 non-null   int64
#  20  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  21  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  22  Curricular units 1st sem (approved)             4424 non-null   int64
#  23  Curricular units 1st sem (grade)                4424 non-null   float64
#  24  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  25  Curricular units 2nd sem (credited)             4424 non-null   int64
#  26  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  27  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  28  Curricular units 2nd sem (approved)             4424 non-null   int64
#  29  Curricular units 2nd sem (grade)                4424 non-null   float64
#  30  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  31  Unemployment rate                               4424 non-null   float64
#  32  Inflation rate                                  4424 non-null   float64
#  33  GDP                                             4424 non-null   float64
#  34  Target                                          4424 non-null   object
# dtypes: float64(5), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
#checking for missing values
data.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %%
data['Target'].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %% [markdown]
# Data Visualisation

# %%
pd.crosstab(data.Target,['Target']).plot(kind='bar')
# Out:
# <Axes: xlabel='Target'>

# %%
pd.crosstab(data.Target,['Target']).plot(kind='pie',subplots=True,autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='Target'>], dtype=object)

# %%
#pp.ProfileReport(data)

# %%
#Dropping rows for enrolled students as this does not indicate the future outcome
data = data.drop(data[data['Target'] == 'Enrolled'].index)

# %%
label_encoder = LabelEncoder()

# Apply label encoding to non-numerical columns
columns_to_encode = ['Target']
for column in columns_to_encode:
    data[column] = label_encoder.fit_transform(data[column])

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
#for i in data.columns: 
 #   sns.countplot(x = i, data = data)
  #  plt.show()

# %%
# Create a heat map
correlation_matrix = data.corr()

# Plot the heatmap
plt.figure(figsize=(26, 12))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# %%
train = data.copy()
target = train.pop('Target')
train.head(2)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
#
#    Inflation rate   GDP
# 0             1.4  1.74
# 1            -0.3  0.79
#
# [2 rows x 34 columns]

# %% [markdown]
# Feature Selection

# %%
num_features_opt = 25   # the number of features that we need to choose as a result
num_features_max = 35  
features_best = []

# %% [markdown]
# Uisng Pearson Correlation

# %%
# Threshold for removing correlated variables
threshold = 0.9

def highlight(value):
    if value > threshold:
        style = 'background-color: pink'
    else:
        style = 'background-color: palegreen'
    return style

# Absolute value correlation matrix
corr_matrix = data.corr().abs().round(2)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
upper.style.format("{:.2f}").applymap(highlight)
# Out:
# <style type="text/css">
# #T_13d73_row0_col0, #T_13d73_row0_col1, #T_13d73_row0_col2, #T_13d73_row0_col3, #T_13d73_row0_col4, #T_13d73_row0_col5, #T_13d73_row0_col6, #T_13d73_row0_col7, #T_13d73_row0_col8, #T_13d73_row0_col9, #T_13d73_row0_col10, #T_13d73_row0_col11, #T_13d73_row0_col12, #T_13d73_row0_col13, #T_13d73_row0_col14, #T_13d73_row0_col15, #T_13d73_row0_col16, #T_13d73_row0_col17, #T_13d73_row0_col18, #T_13d73_row0_col19, #T_13d73_row0_col20, #T_13d73_row0_col21, #T_13d73_row0_col22, #T_13d73_row0_col23, #T_13d73_row0_col24, #T_13d73_row0_col25, #T_13d73_row0_col26, #T_13d73_row0_col27, #T_13d73_row0_col28, #T_13d73_row0_col29, #T_13d73_row0_col30, #T_13d73_row0_col31, #T_13d73_row0_col32, #T_13d73_row0_col33, #T_13d73_row0_col34, #T_13d73_row1_col0, #T_13d73_row1_col1, #T_13d73_row1_col2, #T_13d73_row1_col3, #T_13d73_row1_col4, #T_13d73_row1_col5, #T_13d73_row1_col6, #T_13d73_row1_col7, #T_13d73_row1_col8, #T_13d73_row1_col9, #T_13d73_row1_col10, #T_13d73_row1_col11, #T_13d73_row1_col12, #T_13d73_row1_col13, #T_13d73_row1_col14, #T_13d73_row1_col15, #T_13d73_row1_col16, #T_13d73_row1_col17, #T_13d73_row1_col18, #T_13d73_row1_col19, #T_13d73_row1_col20, #T_13d73_row1_col21, #T_13d73_row1_col22, #T_13d73_row1_col23, #T_13d73_row1_col24, #T_13d73_row1_col25, #T_13d73_row1_col26, #T_13d73_row1_col27, #T_13d73_row1_col28, #T_13d73_row1_col29, #T_13d73_row1_col30, #T_13d73_row1_col31, #T_13d73_row1_col32, #T_13d73_row1_col33, #T_13d73_row1_col34, #T_13d73_row2_col0, #T_13d73_row2_col1, #T_13d73_row2_col2, #T_13d73_row2_col3, #T_13d73_row2_col4, #T_13d73_row2_col5, #T_13d73_row2_col6, #T_13d73_row2_col7, #T_13d73_row2_col8, #T_13d73_row2_col9, #T_13d73_row2_col10, #T_13d73_row2_col11, #T_13d73_row2_col12, #T_13d73_row2_col13, #T_13d73_row2_col14, #T_13d73_row2_col15, #T_13d73_row2_col16, #T_13d73_row2_col17, #T_13d73_row2_col18, #T_13d73_row2_col19, #T_13d73_row2_col20, #T_13d73_row2_col21, #T_13d73_row2_col22, #T_13d73_row2_col23, #T_13d73_row2_col24, #T_13d73_row2_col25, #T_13d73_row2_col26, #T_13d73_row2_col27, #T_13d73_row2_col28, #T_13d73_row2_col29, #T_13d73_row2_col30, #T_13d73_row2_col31, #T_13d73_row2_col32, #T_13d73_row2_col33, #T_13d73_row2_col34, #T_13d73_row3_col0, #T_13d73_row3_col1, #T_13d73_row3_col2, #T_13d73_row3_col3, #T_13d73_row3_col4, #T_13d73_row3_col5, #T_13d73_row3_col6, #T_13d73_row3_col7, #T_13d73_row3_col8, #T_13d73_row3_col9, #T_13d73_row3_col10, #T_13d73_row3_col11, #T_13d73_row3_col12, #T_13d73_row3_col13, #T_13d73_row3_col14, #T_13d73_row3_col15, #T_13d73_row3_col16, #T_13d73_row3_col17, #T_13d73_row3_col18, #T_13d73_row3_col19, #T_13d73_row3_col20, #T_13d73_row3_col21, #T_13d73_row3_col22, #T_13d73_row3_col23, #T_13d73_row3_col24, #T_13d73_row3_col25, #T_13d73_row3_col26, #T_13d73_row3_col27, #T_13d73_row3_col28, #T_13d73_row3_col29, #T_13d73_row3_col30, #T_13d73_row3_col31, #T_13d73_row3_col32, #T_13d73_row3_col33, #T_13d73_row3_col34, #T_13d73_row4_col0, #T_13d73_row4_col1, #T_13d73_row4_col2, #T_13d73_row4_col3, #T_13d73_row4_col4, #T_13d73_row4_col5, #T_13d73_row4_col6, #T_13d73_row4_col7, #T_13d73_row4_col8, #T_13d73_row4_col9, #T_13d73_row4_col10, #T_13d73_row4_col11, #T_13d73_row4_col12, #T_13d73_row4_col13, #T_13d73_row4_col14, #T_13d73_row4_col15, #T_13d73_row4_col16, #T_13d73_row4_col17, #T_13d73_row4_col18, #T_13d73_row4_col19, #T_13d73_row4_col20, #T_13d73_row4_col21, #T_13d73_row4_col22, #T_13d73_row4_col23, #T_13d73_row4_col24, #T_13d73_row4_col25, #T_13d73_row4_col26, #T_13d73_row4_col27, #T_13d73_row4_col28, #T_13d73_row4_col29, #T_13d73_row4_col30, #T_13d73_row4_col31, #T_13d73_row4_col32, #T_13d73_row4_col33, #T_13d73_row4_col34, #T_13d73_row5_col0, #T_13d73_row5_col1, #T_13d73_row5_col2, #T_13d73_row5_col3, #T_13d73_row5_col4, #T_13d73_row5_col5, #T_13d73_row5_col6, #T_13d73_row5_col7, #T_13d73_row5_col8, #T_13d73_row5_col9, #T_13d73_row5_col10, #T_13d73_row5_col11, #T_13d73_row5_col12, #T_13d73_row5_col13, #T_13d73_row5_col14, #T_13d73_row5_col15, #T_13d73_row5_col16, #T_13d73_row5_col17, #T_13d7 ...

# %%
# Select columns with correlations above threshold
collinear_features = [column for column in upper.columns if any(upper[column] > threshold)]
features_filtered = data.drop(columns = collinear_features)
print('The number of features that passed the collinearity threshold: ', features_filtered.shape[1])
features_best.append(features_filtered.columns.tolist())
# Out:
# The number of features that passed the collinearity threshold:  31

# %% [markdown]
# Using SelectFromModel with LinearSCV

# %%
lsvc = LinearSVC(C=0.1, penalty="l1", dual=False).fit(train, target)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(train)
X_selected_df = pd.DataFrame(X_new, columns=[train.columns[i] for i in range(len(train.columns)) if model.get_support()[i]])
features_best.append(X_selected_df.columns.tolist())

# %% [markdown]
# Using Recursive Feature Elimination (RFE) with Logistic Regression

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_features_max, step=10, verbose=5)
rfe_selector.fit(train, target)
rfe_support = rfe_selector.get_support()
rfe_feature = train.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 34 selected features

# %% [markdown]
# Using Recursive Feature Elimination (RFE) with Random Forest

# %%
embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=200), threshold='1.25*median')
embeded_rf_selector.fit(train, target)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(n_estimators=200),
#                 threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = train.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 11 selected features

# %%
features_best.append(embeded_rf_feature)

# %% [markdown]
# Using Variance Threshold

# %%
selector = VarianceThreshold(threshold=10)
np.shape(selector.fit_transform(data))
features_best.append(list(np.array(data.columns)[selector.get_support(indices=False)]))

# %%
#selecting the best features
features_best
# Out:
# [['Marital status',
#   'Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   'Nacionality',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Displaced',
#   'Educational special needs',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'Inflation rate',
#   'GDP',
#   'Target'],
#  ['Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Displaced',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'Age at enrollment',
#   'International',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (credited)',
#   'Curricular units 2nd sem (enrolled)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'GDP'],
#  ['Course',
#   "Father's occupation",
#   'Tuition fees up to date',
#   'Age at enrollment',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (enrolled)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (grade)'],
#  ['Application mode',
#   'Course',
#   'Previous qualification',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Age at enrollment',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (evaluations)',
#   'Curricular units 2nd sem (grade)']]

# %%
# The element is in at least one list of optimal features
main_cols_max = features_best[0]
for i in range(len(features_best)-1):
    main_cols_max = list(set(main_cols_max) | set(features_best[i+1]))
main_cols_max
# Out:
# ['Curricular units 2nd sem (approved)',
#  'International',
#  'Age at enrollment',
#  "Mother's qualification",
#  'Application order',
#  "Father's qualification",
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 1st sem (without evaluations)',
#  'Application mode',
#  'Curricular units 1st sem (enrolled)',
#  'Marital status',
#  'GDP',
#  'Previous qualification',
#  'Curricular units 2nd sem (evaluations)',
#  "Mother's occupation",
#  'Target',
#  'Curricular units 2nd sem (enrolled)',
#  'Course',
#  'Curricular units 1st sem (approved)',
#  "Father's occupation",
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (evaluations)',
#  'Displaced',
#  'Tuition fees up to date',
#  'Daytime/evening attendance',
#  'Educational special needs',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (without evaluations)',
#  'Nacionality',
#  'Inflation rate',
#  'Debtor',
#  'Unemployment rate',
#  'Scholarship holder',
#  'Curricular units 1st sem (grade)',
#  'Gender']

# %%
len(main_cols_max)
# Out:
# 35

# %%
# The element is in all lists of optimal features
main_cols_min = features_best[0]
for i in range(len(features_best)-1):
    main_cols_min = list(set(main_cols_min).intersection(set(features_best[i+1])))
main_cols_min
# Out:
# ['Curricular units 1st sem (evaluations)',
#  'Age at enrollment',
#  'Curricular units 2nd sem (evaluations)',
#  "Father's occupation",
#  'Curricular units 1st sem (approved)',
#  'Course',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 1st sem (grade)']

# %%
# Most common items in all lists of optimal features
main_cols = []
main_cols_opt = {feature_name : 0 for feature_name in data.columns.tolist()}
for i in range(len(features_best)):
    for feature_name in features_best[i]:
        main_cols_opt[feature_name] += 1
df_main_cols_opt = pd.DataFrame.from_dict(main_cols_opt, orient='index', columns=['Target'])
df_main_cols_opt.sort_values(by=['Target'], ascending=False).head(num_features_opt)
# Out:
#                                                 Target
# Age at enrollment                                    4
# Father's occupation                                  4
# Curricular units 2nd sem (evaluations)               4
# Course                                               4
# Curricular units 1st sem (grade)                     4
# Curricular units 1st sem (approved)                  4
# Curricular units 1st sem (evaluations)               4
# Curricular units 2nd sem (grade)                     4
# Application mode                                     3
# Tuition fees up to date                              3
# Mother's occupation                                  3
# Father's qualification                               3
# Mother's qualification                               3
# Previous qualification                               3
# GDP                                                  2
# Application order                                    2
# Curricular units 2nd sem (enrolled)                  2
# Curricular units 2nd sem (without evaluations)       2
# Curricular units 1st sem (without evaluations)       2
# Daytime/evening attendance                           2
# Curricular units 1st sem (credited)                  2
# Curricular units 1st sem (enrolled)                  2
# Displaced                                            2
# Unemployment rate                                    2
# Scholarship holder                                   2

# %%
main_cols = df_main_cols_opt.nlargest(num_features_opt, 'Target').index.tolist()
if not 'Target' in main_cols:
    main_cols.append('Target')
main_cols
# Out:
# ['Course',
#  "Father's occupation",
#  'Age at enrollment',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  'Application mode',
#  'Previous qualification',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  'Tuition fees up to date',
#  'Application order',
#  'Daytime/evening attendance',
#  'Displaced',
#  'Debtor',
#  'Gender',
#  'Scholarship holder',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (approved)',
#  'Target']

# %% [markdown]
# Preparing the model

# %%
from sklearn.model_selection import train_test_split

# %%
data.head(3)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
#
#    Inflation rate   GDP  Target
# 0             1.4  1.74       0
# 1            -0.3  0.79       1
# 2             1.4  1.74       0
#
# [3 rows x 35 columns]

# %%
# Target
target_name = 'Target'
target0 = data['Target']
train0 = data[main_cols].drop([target_name], axis=1)

# %% [markdown]
# Splitting the Data

# %%
from sklearn.model_selection import train_test_split
train,test,target,target_test = train_test_split(train0, target0, test_size = 0.3,random_state=42)

# %%
metrics_all = {1 : 'r2_score', 2: 'acc', 3 : 're', 4 : 'precision', 5: 'f1_score', 6:'recall'}
metrics_now = [1, 2, 3, 4,5,6]

# %%
# list of accuracy of all model
num_models = 6
acc_test = []
acc_all = np.empty((len(metrics_now)*2, 0)).tolist()
acc_all
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], []]

# %%
acc_all_pred = np.empty((len(metrics_now), 0)).tolist()
acc_all_pred
# Out:
# [[], [], [], [], [], []]

# %%
# Splitting train data for model tuning with cross-validation
from sklearn.model_selection import ShuffleSplit
test_train_split_part = 0.2
cv_n_split = 3
random_state = 40

cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)

# %%
def acc_d(y_meas, y_pred):
    # Relative error between predicted y_pred and measured y_meas values
    return mean_absolute_error(y_meas, y_pred)*len(y_meas)/sum(abs(y_meas))

# %%
def plot_cm(target_test, test_pred):
    # Building the confusion matrices
    
    def cm_calc(y_true, y_pred):
        cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
        cm_sum = np.sum(cm, axis=1, keepdims=True)
        cm_perc = cm / cm_sum.astype(float) * 100
        annot = np.empty_like(cm).astype(str)
        nrows, ncols = cm.shape
        for i in range(nrows):
            for j in range(ncols):
                c = cm[i, j]
                p = cm_perc[i, j]
                if i == j:
                    s = cm_sum[i]
                    annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                elif c == 0:
                    annot[i, j] = ''
                else:
                    annot[i, j] = '%.1f%%\n%d' % (p, c)
        cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
        cm.index.name = 'Actual'
        cm.columns.name = 'Predicted'
        return cm, annot

    
    # Building the confusion matrices
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 6), sharex=True)
    
    # Test data
    ax.set_title("for test (validation) data")
    cm1, annot1 = cm_calc(target_test, test_pred)
    sns.heatmap(cm1, cmap= "YlGnBu", annot=annot1, fmt='', ax=ax)
    
    fig.suptitle('CONFUSION MATRICES')
    plt.show()

# %%
def acc_metrics_calc(num,model,train,test,target,target_test):
    # The models selection stage
    # Calculation of accuracy of model by different metrics
    global acc_all

    ytest = model.predict(test).astype(int)
    if num != 17:
        print('target_test =', target_test[:5].values)
        print('ytest =', ytest[:5])

    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_test = round(r2_score(target_test, ytest) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_test = round(metrics.accuracy_score(target_test, ytest) * 100, 2)
        elif x == 3:
            #relative error criterion
            acc_test = round(acc_d(target_test, ytest) * 100, 2)
        elif x == 4:
            # precision score criterion
            precision_test = round(metrics.precision_score(target_test, ytest) * 100, 2)
        elif x == 5:
            # F1 score criterion
            f1_score_test = round(metrics.f1_score(target_test, ytest) * 100, 2)
        elif x == 6:
            # recall score criterion
            recall_test = round(metrics.recall_score(target_test, ytest) * 100, 2)
    
        
        print(metrics_all[x], '=', acc_test)
        acc_all[num_acc+1].append(acc_test) #test
        num_acc += 2
    
    #  Building the confusion matrices
    plot_cm(target_test, ytest)

# %%
def acc_metrics_calc_pred(num,model,name_model,train,test,target):
    # The prediction stage
    # Calculation of accuracy of model for all different metrics and creates of the main submission file for the best model (num=0)
    global acc_all_pred

    ytrain = model.predict(train).astype(int)
    ytest = model.predict(test).astype(int)

    print('**********')
    print(name_model)
    if num != 17:
        print('target = ', target[:15].values)
        print('ytrain = ', ytrain[:15])
        print('ytest =', ytest[:15])
    
    num_acc = 0
    for x in metrics_now:
        if x == 1:
            #r2_score criterion
            acc_train = round(r2_score(target, ytrain) * 100, 2)
        elif x == 2:
            #accuracy_score criterion
            acc_train = round(metrics.accuracy_score(target, ytrain) * 100, 2)
        
        elif x == 3:
            #relative error criterion
            acc_train = round(acc_d(target, ytrain) * 100, 2)
        elif x == 4:
            #precision score criterion
            precision = round(metrics.precision_score(target, ytrain) * 100, 2)
        elif x == 5:
            #F1 score criterion
            f1_score = round(metrics.f1_score(target, ytrain) * 100, 2)
        elif x == 6:
            #recall score criterion
            recall = round(metrics.recall_score(target, ytrain) * 100, 2)     


        print('acc of', metrics_all[x], 'for train =', acc_train)
        acc_all_pred[num_acc].append(acc_train) #train
        num_acc += 1
    
    # Save the submission file
    submission[target_name] = ytest
    submission.to_csv('submission_' + name_model + '.csv', index=False)

# %% [markdown]
# Tuning and Testing features

# %%
# Thanks to https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html#sphx-glr-auto-examples-model-selection-plot-learning-curve-py
def plot_learning_curve(estimator, title, X, y, cv=None, axes=None, ylim=None, 
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5), random_state=0):
    fig, axes = plt.subplots(2, 1, figsize=(20, 10))
    
    if axes is None:
        _, axes = plt.subplots(1, 2, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    axes[0].set_xlabel("Training examples")
    axes[0].set_ylabel("Score")

    cv_train = ShuffleSplit(n_splits=cv_n_split, test_size=test_train_split_part, random_state=random_state)
    
    train_sizes, train_scores, test_scores, fit_times, _ = \
        learning_curve(estimator=estimator, X=X, y=y, cv=cv,
                       train_sizes=train_sizes,
                       return_times=True)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # Plot learning curve
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    axes[0].legend(loc="best")

    # Plot n_samples vs fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, 'o-')
    axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                         fit_times_mean + fit_times_std, alpha=0.1)
    axes[1].set_xlabel("Training examples")
    axes[1].set_ylabel("fit_times")
    axes[1].set_title("Scalability of the model")

    plt.show()
    return

# %% [markdown]
# Support Vector Machines

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(train, target)
print(svr_CV.best_params_)
acc_metrics_calc(1,svr_CV,train,test,target,target_test)
# Out:
# {'kernel': 'linear', 'tol': 0.001}
# target_test = [1 0 0 1 0]
# ytest = [1 0 0 1 0]
# r2_score = 63.37
# acc = 91.37
# re = 13.93
# precision = 13.93
# f1_score = 13.93
# recall = 13.93

# %%
# Building learning curve of model
plot_learning_curve(svr, "Support Vector Machines", train, target, cv=cv_train)

# %% [markdown]
# MLP Classifier

# %%
# %%time
# MLPClassifier

mlp = MLPClassifier()
param_grid = {'hidden_layer_sizes': [i for i in range(2,5)],
              'solver': ['sgd'],
              'learning_rate': ['adaptive'],
              'max_iter': [1000]
              }
mlp_GS = GridSearchCV(mlp, param_grid=param_grid, cv=cv_train, verbose=False)
mlp_GS.fit(train, target)
print(mlp_GS.best_params_)
acc_metrics_calc(3,mlp_GS,train,test,target,target_test)
# Out:
# {'hidden_layer_sizes': 4, 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
# target_test = [1 0 0 1 0]
# ytest = [1 1 0 1 0]
# r2_score = 61.42
# acc = 90.91
# re = 14.67
# precision = 14.67
# f1_score = 14.67
# recall = 14.67
# CPU times: total: 11.6 s
# Wall time: 14.4 s

# %%
# Building learning curve of model
plot_learning_curve(mlp, "MLP Classifier", train, target, cv=cv_train)

# %% [markdown]
# Stochastic Gradient Descent

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier(early_stopping=True)
param_grid = {'alpha': [0.035, 0.04, 0.45]}
sgd_CV = GridSearchCV(sgd, param_grid=param_grid, cv=cv_train, verbose=False)
sgd_CV.fit(train, target)
print(sgd_CV.best_params_)
acc_metrics_calc(4,sgd_CV,train,test,target,target_test)
# Out:
# {'alpha': 0.45}
# target_test = [1 0 0 1 0]
# ytest = [1 1 0 1 0]
# r2_score = 55.19
# acc = 89.44
# re = 17.04
# precision = 17.04
# f1_score = 17.04
# recall = 17.04

# %%
# Building learning curve of model
plot_learning_curve(sgd, "Stochastic Gradient Descent", train, target, cv=cv_train)

# %% [markdown]
# Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
param_grid = {'min_samples_leaf': [i for i in range(2,10)]}
decision_tree_CV = GridSearchCV(decision_tree, param_grid=param_grid, cv=cv_train, verbose=False)
decision_tree_CV.fit(train, target)
print(decision_tree_CV.best_params_)
acc_metrics_calc(5,decision_tree_CV,train,test,target,target_test)
# Out:
# {'min_samples_leaf': 8}
# target_test = [1 0 0 1 0]
# ytest = [1 0 0 1 0]
# r2_score = 52.07
# acc = 88.71
# re = 18.22
# precision = 18.22
# f1_score = 18.22
# recall = 18.22

# %%
# Building learning curve of model
plot_learning_curve(decision_tree_CV, "Decision Tree", train, target, cv=cv_train)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (2.0.0)
# Requirement already satisfied: numpy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\okechukwu chude\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.11.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost as xgb

# %%
# %%time
# XGBoost Classifier
xgb_clf = xgb.XGBClassifier(objective='reg:squarederror') 
parameters = {'n_estimators': [50, 60, 70, 80, 90], 
              'learning_rate': [0.09, 0.1, 0.15, 0.2],
              'max_depth': [3, 4, 5]}
xgb_reg = GridSearchCV(estimator=xgb_clf, param_grid=parameters, cv=cv_train).fit(train, target)
print("Best score: %0.3f" % xgb_reg.best_score_)
print("Best parameters set:", xgb_reg.best_params_)
acc_metrics_calc(7,xgb_reg,train,test,target,target_test)
# Out:
# Best score: 0.900
# Best parameters set: {'learning_rate': 0.09, 'max_depth': 4, 'n_estimators': 50}
# target_test = [1 0 0 1 0]
# ytest = [1 0 0 1 0]
# r2_score = 59.08
# acc = 90.36
# re = 15.56
# precision = 15.56
# f1_score = 15.56
# recall = 15.56
# CPU times: total: 1min 40s
# Wall time: 15.4 s

# %%
# Building learning curve of model
plot_learning_curve(xgb_clf, "XGBoost Classifier", train, target, cv=cv_train)

# %% [markdown]
# Neural Network with Keras

# %%
def build_nn(optimizer='adam'):

    # Initializing the NN
    nn = Sequential()

    # Adding the input layer and the first hidden layer of the NN
    nn.add(Dense(units=32, kernel_initializer='he_normal', activation='relu', input_shape=(len(train0.columns),)))
    # Adding the output layer
    nn.add(Dense(units=1, kernel_initializer='he_normal', activation='sigmoid'))

    # Compiling the NN
    nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return nn

Xtrain, Xval, Ztrain, Zval = train_test_split(train, target, test_size=test_train_split_part, random_state=random_state)
nn_model = build_nn(optimizers.Adam(lr=0.0001))
nn_model.fit(Xtrain, Ztrain, batch_size=16, epochs=100, validation_data=(Xval, Zval))
acc_metrics_calc(17,nn_model,train,test,target,target_test)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 127/127 [==============================] - 1s 4ms/step - loss: 0.9860 - accuracy: 0.6954 - val_loss: 0.5919 - val_accuracy: 0.7819
# Epoch 2/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.5265 - accuracy: 0.7953 - val_loss: 0.4346 - val_accuracy: 0.8212
# Epoch 3/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8278 - val_loss: 0.3498 - val_accuracy: 0.8566
# Epoch 4/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3726 - accuracy: 0.8479 - val_loss: 0.3354 - val_accuracy: 0.8703
# Epoch 5/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3466 - accuracy: 0.8484 - val_loss: 0.2997 - val_accuracy: 0.8959
# Epoch 6/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3213 - accuracy: 0.8730 - val_loss: 0.3213 - val_accuracy: 0.8861
# Epoch 7/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.3147 - accuracy: 0.8642 - val_loss: 0.2783 - val_accuracy: 0.9018
# Epoch 8/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.3068 - accuracy: 0.8706 - val_loss: 0.2698 - val_accuracy: 0.8998
# Epoch 9/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2941 - accuracy: 0.8780 - val_loss: 0.2688 - val_accuracy: 0.8998
# Epoch 10/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2834 - accuracy: 0.8804 - val_loss: 0.2652 - val_accuracy: 0.8998
# Epoch 11/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2814 - accuracy: 0.8858 - val_loss: 0.2590 - val_accuracy: 0.9096
# Epoch 12/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.8898 - val_loss: 0.2523 - val_accuracy: 0.9096
# Epoch 13/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2713 - accuracy: 0.8888 - val_loss: 0.2611 - val_accuracy: 0.9194
# Epoch 14/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.8971 - val_loss: 0.2554 - val_accuracy: 0.9175
# Epoch 15/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.8957 - val_loss: 0.2596 - val_accuracy: 0.9175
# Epoch 16/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2579 - accuracy: 0.8986 - val_loss: 0.2490 - val_accuracy: 0.9155
# Epoch 17/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2587 - accuracy: 0.8971 - val_loss: 0.2446 - val_accuracy: 0.9214
# Epoch 18/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.8917 - val_loss: 0.3033 - val_accuracy: 0.8900
# Epoch 19/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2523 - accuracy: 0.9035 - val_loss: 0.2421 - val_accuracy: 0.9155
# Epoch 20/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.9021 - val_loss: 0.2332 - val_accuracy: 0.9253
# Epoch 21/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2555 - accuracy: 0.8991 - val_loss: 0.2478 - val_accuracy: 0.9175
# Epoch 22/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2621 - accuracy: 0.8986 - val_loss: 0.2898 - val_accuracy: 0.8802
# Epoch 23/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.9070 - val_loss: 0.2410 - val_accuracy: 0.9234
# Epoch 24/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.9060 - val_loss: 0.2510 - val_accuracy: 0.9175
# Epoch 25/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9050 - val_loss: 0.2347 - val_accuracy: 0.9234
# Epoch 26/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2494 - accuracy: 0.9075 - val_loss: 0.2369 - val_accuracy: 0.9293
# Epoch 27/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2571 - accuracy: 0.8986 - val_loss: 0.2367 - val_accuracy: 0.9273
# Epoch 28/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.9035 - val_loss: 0.2529 - val_accuracy: 0.9175
# Epoch 29/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2416 - accuracy: 0.9080 - val_loss: 0.2384 - val_accuracy: 0.9234
# Epoch 30/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2609 - accuracy: 0.8967 - val_loss: 0.2383 - val_accuracy: 0.9234
# Epoch 31/100
# 127/127 [==============================] - 0s 4ms/step - loss: 0.2431 - accuracy: 0.9055 - val_loss: 0.2351 - val_accuracy: 0.9253
# Epoch 32/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9026 - val_loss: 0.2469 - val_accuracy: 0.9175
# Epoch 33/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9109 - val_loss: 0.2312 - val_accuracy: 0.9273
# Epoch 34/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9094 - val_loss: 0.2430 - val_accuracy: 0.9234
# Epoch 35/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9075 - val_loss: 0.2672 - val_accuracy: 0.9155
# Epoch 36/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.9104 - val_loss: 0.2391 - val_accuracy: 0.9214
# Epoch 37/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2396 - accuracy: 0.9070 - val_loss: 0.3001 - val_accuracy: 0.8802
# Epoch 38/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2445 - accuracy: 0.9050 - val_loss: 0.2462 - val_accuracy: 0.9234
# Epoch 39/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2441 - accuracy: 0.9090 - val_loss: 0.2539 - val_accuracy: 0.9096
# Epoch 40/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2352 - accuracy: 0.9114 - val_loss: 0.2680 - val_accuracy: 0.9077
# Epoch 41/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9124 - val_loss: 0.2329 - val_accuracy: 0.9312
# Epoch 42/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9129 - val_loss: 0.2385 - val_accuracy: 0.9214
# Epoch 43/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.9149 - val_loss: 0.2555 - val_accuracy: 0.9136
# Epoch 44/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9094 - val_loss: 0.2397 - val_accuracy: 0.9234
# Epoch 45/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.9075 - val_loss: 0.2395 - val_accuracy: 0.9214
# Epoch 46/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9144 - val_loss: 0.2398 - val_accuracy: 0.9214
# Epoch 47/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9109 - val_loss: 0.2344 - val_accuracy: 0.9194
# Epoch 48/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.9104 - val_loss: 0.2394 - val_accuracy: 0.9234
# Epoch 49/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2299 - accuracy: 0.9139 - val_loss: 0.2913 - val_accuracy: 0.8900
# Epoch 50/100
# 127/127 [==============================] - 1s 5ms/step - loss: 0.2298 - accuracy: 0.9114 - val_loss: 0.2404 - val_accuracy: 0.9155
# Epoch 51/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.9094 - val_loss: 0.2295 - val_accuracy: 0.9293
# Epoch 52/100
# 127/127 [==============================] - 0s 4ms/step - loss: 0.2314 - accuracy: 0.9173 - val_loss: 0.2314 - val_accuracy: 0.9253
# Epoch 53/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2288 - accuracy: 0.9109 - val_loss: 0.2389 - val_accuracy: 0.9214
# Epoch 54/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2304 - accuracy: 0.9065 - val_loss: 0.2369 - val_accuracy: 0.9214
# Epoch 55/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2273 - accuracy: 0.9104 - val_loss: 0.2305 - val_accuracy: 0.9273
# Epoch 56/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2237 - accuracy: 0.9208 - val_loss: 0.2328 - val_accuracy: 0.9234
# Epoch 57/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2258 - accuracy: 0.9149 - val_loss: 0.2389 - val_accuracy: 0.9175
# Epoch 58/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2215 - accuracy: 0.9158 - val_loss: 0.2438 - val_accuracy: 0.9194
# Epoch 59/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.9213 - val_loss: 0.2680 - val_accuracy: 0.9037
# Epoch 60/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2267 - accuracy: 0.9173 - val_loss: 0.2436 - val_accuracy: 0.9175
# Epoch 61/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2249 - accuracy: 0.9124 - val_loss: 0.2509 - val_accuracy: 0.9175
# Epoch 62/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2210 - accuracy: 0.9144 - val_loss: 0.2546 - val_accuracy: 0.9155
# Epoch 63/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2239 - accuracy: 0.9134 - val_loss: 0.2487 - val_accuracy: 0.9116
# Epoch 64/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.9134 - val_loss: 0.2566 - val_accuracy: 0.9116
# Epoch 65/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2361 - accuracy: 0.9104 - val_loss: 0.2947 - val_accuracy: 0.9037
# Epoch 66/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2262 - accuracy: 0.9158 - val_loss: 0.2376 - val_accuracy: 0.9214
# Epoch 67/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2207 - accuracy: 0.9193 - val_loss: 0.2471 - val_accuracy: 0.9194
# Epoch 68/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2206 - accuracy: 0.9178 - val_loss: 0.2928 - val_accuracy: 0.8861
# Epoch 69/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2246 - accuracy: 0.9168 - val_loss: 0.2344 - val_accuracy: 0.9253
# Epoch 70/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9144 - val_loss: 0.2356 - val_accuracy: 0.9194
# Epoch 71/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 0.9188 - val_loss: 0.2395 - val_accuracy: 0.9175
# Epoch 72/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2248 - accuracy: 0.9178 - val_loss: 0.3128 - val_accuracy: 0.8762
# Epoch 73/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2179 - accuracy: 0.9208 - val_loss: 0.2382 - val_accuracy: 0.9234
# Epoch 74/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2167 - accuracy: 0.9178 - val_loss: 0.2384 - val_accuracy: 0.9175
# Epoch 75/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2185 - accuracy: 0.9213 - val_loss: 0.2643 - val_accuracy: 0.9096
# Epoch 76/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2193 - accuracy: 0.9144 - val_loss: 0.2531 - val_accuracy: 0.9116
# Epoch 77/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2169 - accuracy: 0.9163 - val_loss: 0.2364 - val_accuracy: 0.9253
# Epoch 78/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2210 - accuracy: 0.9218 - val_loss: 0.2448 - val_accuracy: 0.9155
# Epoch 79/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2155 - accuracy: 0.9178 - val_loss: 0.2524 - val_accuracy: 0.9116
# Epoch 80/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2186 - accuracy: 0.9178 - val_loss: 0.2396 - val_accuracy: 0.9194
# Epoch 81/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.9218 - val_loss: 0.2410 - val_accuracy: 0.9234
# Epoch 82/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2138 - accuracy: 0.9218 - val_loss: 0.2468 - val_accuracy: 0.9214
# Epoch 83/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9188 - val_loss: 0.2444 - val_accuracy: 0.9194
# Epoch 84/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2113 - accuracy: 0.9208 - val_loss: 0.2465 - val_accuracy: 0.9214
# Epoch 85/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.9242 - val_loss: 0.2418 - val_accuracy: 0.9234
# Epoch 86/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2153 - accuracy: 0.9173 - val_loss: 0.2386 - val_accuracy: 0.9214
# Epoch 87/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2205 - accuracy: 0.9218 - val_loss: 0.2402 - val_accuracy: 0.9234
# Epoch 88/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2206 - accuracy: 0.9173 - val_loss: 0.2484 - val_accuracy: 0.9155
# Epoch 89/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2138 - accuracy: 0.9213 - val_loss: 0.2634 - val_accuracy: 0.9136
# Epoch 90/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2089 - accuracy: 0.9213 - val_loss: 0.2565 - val_accuracy: 0.9077
# Epoch 91/100
# 127/127 [==============================] - 0s 3ms/step - loss: 0.2170 - accuracy: 0.9203 - val_loss: 0.2409 - val_accuracy: 0.9253
# Epoch 92/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9237 - val_loss: 0.2416 - val_accuracy: 0.9194
# Epoch 93/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.9218 - val_loss: 0.2430 - val_accuracy: 0.9194
# Epoch 94/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2191 - accuracy: 0.9208 - val_loss: 0.2610 - val_accuracy: 0.9136
# Epoch 95/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2071 - accuracy: 0.9242 - val_loss: 0.2403 - val_accuracy: 0.9253
# Epoch 96/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2084 - accuracy: 0.9237 - val_loss: 0.2432 - val_accuracy: 0.9273
# Epoch 97/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2104 - accuracy: 0.9222 - val_loss: 0.2463 - val_accuracy: 0.9214
# Epoch 98/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2130 - accuracy: 0.9193 - val_loss: 0.2634 - val_accuracy: 0.9155
# Epoch 99/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2113 - accuracy: 0.9227 - val_loss: 0.2526 - val_accuracy: 0.9175
# Epoch 100/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.2112 - accuracy: 0.9213 - val_loss: 0.2594 - val_accuracy: 0.9116
# 35/35 [==============================] - 0s 1ms/step
# r2_score = -162.65
# acc = 38.11
# re = 99.85
# precision = 99.85
# f1_score = 99.85
# recall = 99.85

# %% [markdown]
# Gaussian Process

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
print(gpc_CV.best_params_)
acc_metrics_calc(18,gpc_CV,train,test,target,target_test)
# Out:
# {'max_iter_predict': 70, 'n_restarts_optimizer': 2, 'warm_start': False}
# target_test = [1 0 0 1 0]
# ytest = [0 1 0 1 0]
# r2_score = 18.16
# acc = 80.72
# re = 31.11
# precision = 31.11
# f1_score = 31.11
# recall = 31.11

# %%
# Building learning curve of model
plot_learning_curve(gpc, "Gaussian Process Classification", train, target, cv=cv_train)

# %% [markdown]
# Model Evaluation

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines','MLP Classifier', 'Stochastic Gradient Decent', 'Decision Tree Classifier','XGB Classifier',
              'NN model', 'Gaussian Process Classification'  ]})

# %%
for x in metrics_now:
    xs = metrics_all[x]
    models[xs + '_test'] = acc_all[(x-1)*2+1]

# %%
print('Prediction accuracy for models')
ms = metrics_all[metrics_now[1]] # the first from metrics
models[['Model',  ms + '_test']].sort_values(by=[(ms + '_test')], ascending=False)
# Out:
# Prediction accuracy for models
#                              Model  acc_test
# 0          Support Vector Machines     91.37
# 1                   MLP Classifier     90.91
# 4                   XGB Classifier     90.36
# 2       Stochastic Gradient Decent     89.44
# 3         Decision Tree Classifier     88.71
# 6  Gaussian Process Classification     80.72
# 5                         NN model     38.11

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
for x in metrics_now:   
    # Plot
    xs = metrics_all[x]
    xs_test = metrics_all[x] + '_test'
    plt.figure(figsize=[15,6])
    xx = models['Model']
    plt.tick_params(labelsize=14)
    plt.plot(xx, models[xs_test], label = xs_test)
    plt.legend()
    plt.title(str(xs) + ' criterion for ' + str(num_models) + ' models for train and test datasets')
    plt.xlabel('Models')
    plt.ylabel(xs + ', %')
    plt.xticks(xx, rotation='vertical')
    plt.show()

# %% [markdown]
# Extension

# %%
# Split the data and targets into training/testing sets
X_train, X_test, y_train, y_test = train_test_split(
        train, target, test_size=0.2, random_state=3)

# %%
# Support Vector Machines
from sklearn.model_selection import GridSearchCV
svr = SVC()
svr_CV = GridSearchCV(svr, param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                                       'tol': [1e-3]}, 
                      cv=cv_train, verbose=False)
svr_CV.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=40, test_size=0.2, train_size=None),
#              estimator=SVC(),
#              param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                          'tol': [0.001]},
#              verbose=False)

# %%
print(svr_CV.best_params_)
acc_metrics_calc(1,svr_CV,train,test,target,target_test)
# Out:
# {'kernel': 'linear', 'tol': 0.001}
# target_test = [1 0 0 1 0]
# ytest = [1 0 0 1 0]
# r2_score = 62.59
# acc = 91.18
# re = 14.22
# precision = 14.22
# f1_score = 14.22
# recall = 14.22

# %%
# Make predictions using the testing set
svr_pred = svr_CV.predict(X_test)

# %%
#Using two features in the data set for plotting possibility. We can take any 2
svr_X_train = X_train.iloc[:, [2, 10]]
svr_y_train= y_train

# %%
svr_X_train.head()
# Out:
#       Age at enrollment  Mother's qualification
# 433                  19                       1
# 3261                 19                       1
# 690                  48                      22
# 4263                 30                      22
# 2170                 19                       1

# %%
h = .02  # step size in the mesh

svr_CV.fit(svr_X_train, svr_y_train)

svr_X = X_test.iloc[:, [2,3]]
svr_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = svr_X.iloc[:, 0].min() - 1, svr_X.iloc[:, 0].max() + 1
y_min, y_max = svr_X.iloc[:, 1].min() - 1, svr_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = svr_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(svr_X.iloc[:, 0], svr_X.iloc[:, 1], c=svr_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
sp = time.time()
time_taken = sp-st
print('This project took', time_taken, 'seconds to execute')
# Out:
# This project took 1672.6373381614685 seconds to execute

# %% [markdown]
# Cross Validation

# %%
gpc = GaussianProcessClassifier()
param_grid = {'max_iter_predict': [70, 80, 90],
              'warm_start': [False],
              'n_restarts_optimizer': range(2,4)}
gpc_CV = GridSearchCV(estimator=gpc, param_grid=param_grid, cv=cv_train, verbose=False)
gpc_CV.fit(train, target)
print(gpc_CV.best_params_)
acc_metrics_calc(18,gpc_CV,X_train,X_test, y_train, y_test)
# Out:
# {'max_iter_predict': 70, 'n_restarts_optimizer': 2, 'warm_start': False}
# target_test = [0 1 0 1 1]
# ytest = [0 1 0 1 1]
# r2_score = 100.0
# acc = 100.0
# re = 0.0
# precision = 0.0
# f1_score = 0.0
# recall = 0.0

# %%
# Make predictions using the testing set
gaus_pred = gpc_CV.predict(X_test)

# %%
X_train
# Out:
#       Course  Father's occupation  Age at enrollment  \
# 433       12                    4                 19
# 3261       9                    9                 19
# 690        8                    5                 48
# 4263      17                    5                 30
# 2170      12                    9                 19
# ...      ...                  ...                ...
# 1851       7                    8                 18
# 2788      14                    8                 24
# 918        4                    5                 43
# 2237      11                    6                 24
# 480       12                    5                 19
#
#       Curricular units 1st sem (evaluations)  \
# 433                                        7
# 3261                                       5
# 690                                        0
# 4263                                       7
# 2170                                       8
# ...                                      ...
# 1851                                      12
# 2788                                      12
# 918                                        8
# 2237                                       7
# 480                                       10
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 433                                     0                              0.00
# 3261                                    5                             13.40
# 690                                     0                              0.00
# 4263                                    3                             11.67
# 2170                                    7                             13.71
# ...                                   ...                               ...
# 1851                                    5                             13.29
# 2788                                    0                              0.00
# 918                                     6                             14.17
# 2237                                    0                              0.00
# 480                                     6                             11.61
#
#       Curricular units 2nd sem (evaluations)  \
# 433                                        7
# 3261                                       5
# 690                                        0
# 4263                                       8
# 2170                                       8
# ...                                      ...
# 1851                                      16
# 2788                                       9
# 918                                        9
# 2237                                       7
# 480                                        8
#
#       Curricular units 2nd sem (grade)  Application mode  \
# 433                               0.00                 1
# 3261                             12.60                 1
# 690                               0.00                12
# 4263                             11.00                12
# 2170                             13.71                 1
# ...                                ...               ...
# 1851                             14.80                 1
# 2788                              0.00                12
# 918                              15.00                15
# 2237                              0.00                12
# 480                              14.04                 1
#
#       Previous qualification  ...  Daytime/evening attendance  Displaced  \
# 433                        1  ...                           1          0
# 3261                       1  ...                           1          1
# 690                       12  ...                           1          0
# 4263                       9  ...                           0          0
# 2170                       1  ...                           1          1
# ...                      ...  ...                         ...        ...
# 1851                       1  ...                           1          0
# 2788                       1  ...                           1          0
# 918                       14  ...                           1          0
# 2237                      12  ...                           1          0
# 480                        1  ...                           1          0
#
#       Debtor  Gender  Scholarship holder  Curricular units 1st sem (credited)  \
# 433        0       0                   1                                    0
# 3261       0       0                   1                                    0
# 690        0       1                   0                                    0
# 4263       0       1                   0                                    0
# 2170       0       0                   0                                    0
# ...      ...     ...                 ...                                  ...
# 1851       0       1                   0                                    0
# 2788       1       1                   0                                    0
# 918        0       0                   0                                    0
# 2237       1       1                   0                                    0
# 480        0       0                   0                                    0
#
#       Curricular units 1st sem (enrolled)  \
# 433                                     7
# 3261                                    5
# 690                                     6
# 4263                                    5
# 2170                                    8
# ...                                   ...
# 1851                                    5
# 2788                                    6
# 918                                     6
# 2237                                    6
# 480                                     7
#
#       Curricular units 1st sem (without evaluations)  \
# 433                                                2
# 3261                                               0
# 690                                                0
# 4263                                               0
# 2170                                               0
# ...                                              ...
# 1851                                               0
# 2788                                               0
# 918                                                0
# 2237                                               0
# 480                                                0
#
#       Curricular units 2nd sem (enrolled)  Curricular units 2nd sem (approved)
# 433                                     7                                    0
# 3261                                    5                                    5
# 690                                     6                                    0
# 4263                                    5                                    1
# 2170                                    8                                    7
# ...                                   ...                                  ...
# 1851                                    5                                    5
# 2788                                    6                                    0
# 918                                     6                                    6
# 2237                                    6                                    0
# 480                                     8                                    8
#
# [2032 rows x 25 columns]

# %%
#Using two features in the data set for plotting possibility. We can take any 2
gaus_X_train = X_train.iloc[:, [2, 10]]
gaus_y_train= y_train

# %%
h = .02  # step size in the mesh

gpc_CV.fit(gaus_X_train, gaus_y_train)

gaus_X = X_test.iloc[:, [2,3]]
gaus_y = y_test

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
                     np.arange(y_min, y_max,h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\okechukwu chude\Documents\MOdeling and optimisation\Predict students' dropout and success\Predict-students--dropout-and-academic-success\Student prediction 2.ipynb Cell 103 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/okechukwu%20chude/Documents/MOdeling%20and%20optimisation/Predict%20students%27%20dropout%20and%20success/Predict-students--dropout-and-academic-success/Student%20prediction%202.ipynb#Y206sZmlsZQ%3D%3D?line=3'>4</a> y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
#       <a href='vscode-notebook-cell:/c%3A/Users/okechukwu%20chude/Documents/MOdeling%20and%20optimisation/Predict%20students%27%20dropout%20and%20success/Predict-students--dropout-and-academic-success/Student%20prediction%202.ipynb#Y206sZmlsZQ%3D%3D?line=4'>5</a> xx, yy = np.meshgrid(np.arange(x_min, x_max,h),
#       <a href='vscode-notebook-cell:/c%3A/Users/okechukwu%20chude/Documents/MOdeling%20and%20optimisation/Predict%20students%27%20dropout%20and%20success/Predict-students--dropout-and-academic-success/Student%20prediction%202.ipynb#Y206sZmlsZQ%3D%3D?line=5'>6</a>                      np.arange(y_min, y_max,h))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/okechukwu%20chude/Documents/MOdeling%20and%20optimisation/Predict%20students%27%20dropout%20and%20success/Predict-students--dropout-and-academic-success/Student%20prediction%202.ipynb#Y206sZmlsZQ%3D%3D?line=6'>7</a> Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])
#
# File c:\Users\okechukwu chude\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:519, in BaseSearchCV.predict(self, X)
#     501 """Call predict on the estimator with the best found parameters.
#     502
#     503 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     516     the best found parameters.
#     517 """
#     518 check_is_fitted(self)
# --> 519 return self.best_estimator_.predict(X)
#
# File c:\Users\okechukwu chude\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\_gpc.py:777, in GaussianProcessClassifier.predict(self, X)
#     774 else:
#     775     X = self._validate_data(X, ensure_2d=False, dtype=None, reset=False)
# --> 777 return self.base_estimator_.predict(X)
#
# File c:\Users\okechukwu chude\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\_gpc.py:288, in _BinaryGaussianProcessClassifierLaplace.predict(self, X)
#     283 check_is_fitted(self)
#     285 # As discussed on Section 3.4.2 of GPML, for making hard binary
#     286 # decisions, it is enough to compute the MAP of the posterior and
#     287 # pass it through the link function
# --> 288 K_star = self.kernel_(self.X_train_, X)  # K_star =k(x_star)
#     289 f_star = K_star.T.dot(self.y_train_ - self.pi_)  # Algorithm 3.2,Line 4
#     291 return np.where(f_star > 0, self.classes_[1], self.classes_[0])
#
# File c:\Users\okechukwu chude\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\kernels.py:945, in Product.__call__(self, X, Y, eval_gradient)
#     941     return K1 * K2, np.dstack(
#     942         (K1_gradient * K2[:, :, np.newaxis], K2_gradient * K1[:, :, np.newaxis])
#     943     )
#     944 else:
# --> 945     return self.k1(X, Y) * self.k2(X, Y)
#
# File c:\Users\okechukwu chude\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\gaussian_process\kernels.py:1252, in ConstantKernel.__call__(self, X, Y, eval_gradient)
#    1249 elif eval_gradient:
#    1250     raise ValueError("Gradient can only be evaluated when Y is None.")
# -> 1252 K = np.full(
#    1253     (_num_samples(X), _num_samples(Y)),
#    1254     self.constant_value,
#    1255     dtype=np.array(self.constant_value).dtype,
#    1256 )
#    1257 if eval_gradient:
#    1258     if not self.hyperparameter_constant_value.fixed:
#
# File c:\Users\okechukwu chude\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\numeric.py:344, in full(shape, fill_value, dtype, order, like)
#     342     fill_value = asarray(fill_value)
#     343     dtype = fill_value.dtype
# --> 344 a = empty(shape, dtype, order)
#     345 multiarray.copyto(a, fill_value, casting='unsafe')
#     346 return a
#
# MemoryError: Unable to allocate 71.2 GiB for an array with shape (2032, 4700000) and data type float64

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Gaussian Process")

plt.show()

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = gaus_X.iloc[:, 0].min() - 1, gaus_X.iloc[:, 0].max() + 1
y_min, y_max = gaus_X.iloc[:, 1].min() - 1, gaus_X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = gpc_CV.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()

# Plot the decision boundary using pcolormesh
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points using scatter
plt.scatter(gaus_X.iloc[:, 0], gaus_X.iloc[:, 1], c=gaus_y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Age at enrollment')
plt.ylabel('Fathers qualification')
plt.title("Support Vector Machines")

plt.show()

# %%
X= train.fit_transform(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X= train.fit_transform(train)
#
# NameError: name 'train' is not defined
